# %% [markdown]
# <h1> Imports

# %%
import pandas as pd
import numpy as np
import os
from matplotlib import pyplot as plt 
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectFdr
from scipy.signal import butter, lfilter, filtfilt, freqz
from scipy import signal

# %% [markdown]
# <h1> Fitlering Functions

# %%
record_export_folder = 'recordings'
# keep_cols = ['EEG.P7', 'EEG.O1', 'EEG.O2', 'EEG.P8'] # ['Timestamp', 'EEG.Counter', 'EEG.P7', 'EEG.O1', 'EEG.O2', 'EEG.P8']
keep_cols = ["O1/theta","O1/alpha","O1/betaL","O1/betaH","O1/gamma",
             "O2/theta","O2/alpha","O2/betaL","O2/betaH","O2/gamma"]

def load_df(file_name):
    file_path = os.path.join(record_export_folder, file_name)
    return pd.read_csv(file_path, skiprows=0, header=0)

def trim_cols(df):
    return df[keep_cols]

# %% [markdown]
# <h1> Data from 4 Sensors

# %%
df = trim_cols(load_df('psychopy_sultan_recording_{}.csv'.format(0)))

# %%
df.values[2]
# Out:
# array([0.809, 1.082, 1.081, 0.868, 0.529, 0.494, 0.476, 0.122, 0.219,
#        0.47 ])

# %%
[0.598, 0.75 , 0.959, 0.85 , 0.64 , 0.63 , 0.54 , 0.099, 0.244,
       0.518]
# Out:
# [0.598, 0.75, 0.959, 0.85, 0.64, 0.63, 0.54, 0.099, 0.244, 0.518]

# %%
subplot = 0
fig, axs = plt.subplots(10)
for col in df.columns:
    axs[subplot].plot(df[col].values)
    subplot += 1

# %% [markdown]
# <h1> Training Data

# %%
from sklearn.preprocessing import minmax_scale

# %%
seconds_to_check = 3
total_data_points = 600
interval_range = int(8 * seconds_to_check)
data_points = int(total_data_points / interval_range)

def split_to_training_data(df):
    total_data = []
    for interval_start in range(0, interval_range * data_points, interval_range):
        temp_data = []
        for col in range(0, df.shape[1]):
            temp_data.append(df[interval_start:interval_start + interval_range, col])
        
        total_data.append(temp_data)
        
    return np.asarray(total_data)

def create_target_data(data, target):
    return np.asarray([target] * data.shape[0])

def scale_and_normalize(data):
    print(data.shape)
    for sample in range(data.shape[0]):
        for col in range(data.shape[1]):
            data[sample,col,:] = minmax_scale(data[sample,col,:])
#         for feature in range(data.shape[1]):
#             data[sample,feature,:] = minmax_scale(data[sample,feature,:])
#             data[:,col] = minmax_scale(data[:,col])
    return data
#     return minmax_scale(data)

# %%
targets = range(0, 4)
total_train_x = []
total_train_y = []
for target in targets:
    df = trim_cols(load_df('psychopy_sultan_recording_{}.csv'.format(target)))
    total_data = np.asarray(df.values)
    train_x = split_to_training_data(total_data)
#     train_x = scale_and_normalize(train_x)
    train_y = create_target_data(train_x, target)
    if target == targets[0]:
        total_train_x = train_x
        total_train_y = train_y
    else:
        total_train_x = np.concatenate((total_train_x, train_x))
        total_train_y = np.concatenate((total_train_y, train_y))

# %%
total_train_x.shape
# Out:
# (100, 10, 24)

# %%
total_train_x[0]
# Out:
# array([[0.598, 0.725, 0.809, 0.808, 0.721, 0.586, 0.461, 0.381, 0.353,
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, SimpleRNN, GRU, BatchNormalization, LayerNormalization, ActivityRegularization
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau, EarlyStopping

# %%
def create_model():
    model = Sequential()
    model.add(LSTM(100, input_shape=(train_x.shape[1:]), return_sequences=True))
#     model.add(Dropout(0.2))
    model.add(ActivityRegularization(l2=0.001))
#     model.add(BatchNormalization())

#     model.add(LSTM(8, input_shape=(train_x.shape[1:]), return_sequences=True))
#     model.add(Dropout(0.3))
#     model.add(ActivityRegularization(l2=0.001))
#     model.add(BatchNormalization())

    model.add(LSTM(20, input_shape=(train_x.shape[1:]), return_sequences=False))
#     model.add(Dropout(0.5))
#     model.add(ActivityRegularization(l2=0.001))
#     model.add(BatchNormalization())

#     model.add(Dense(16))

    model.add(Dense(4, activation="softmax"))
    
    return model

# %%
EPOCHS = 200
BATCH_SIZE = 8
NAME= "models\BEST"

# %%
model = create_model()
    
opt = tf.keras.optimizers.Adam(0.1)

model.compile(loss='sparse_categorical_crossentropy',
              optimizer=opt, metrics=['acc'])

callbacks = [
#     TensorBoard(f"logs\LSTM-{int(time.time())}"),
#     ReduceLROnPlateau(patience=15, factor=0.9),
    EarlyStopping(patience=40),
    ModelCheckpoint(filepath=f"models\Best", monitor='val_loss', verbose=2, save_weights_only=True, save_best_only=True, mode='min')
]
    
history = model.fit(train_x,
                    train_y,
                    batch_size= BATCH_SIZE,
                    epochs = EPOCHS,
                    validation_data=(validation_x, validation_y), 
                    callbacks=callbacks)
# Out:
# Epoch 1/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.3502 - acc: 0.2500
# Epoch 00001: val_loss improved from inf to 1.42616, saving model to models\Best
# 10/10 [==============================] - 1s 78ms/step - loss: 1.4095 - acc: 0.2625 - val_loss: 1.4262 - val_acc: 0.2500
# Epoch 2/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.4848 - acc: 0.1250
# Epoch 00002: val_loss improved from 1.42616 to 1.39442, saving model to models\Best
# 10/10 [==============================] - 0s 9ms/step - loss: 1.4208 - acc: 0.2250 - val_loss: 1.3944 - val_acc: 0.4000
# Epoch 3/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.3699 - acc: 0.2500
# Epoch 00003: val_loss improved from 1.39442 to 1.39281, saving model to models\Best
# 10/10 [==============================] - 0s 9ms/step - loss: 1.4170 - acc: 0.2750 - val_loss: 1.3928 - val_acc: 0.2500
# Epoch 4/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.3804 - acc: 0.2500
# Epoch 00004: val_loss did not improve from 1.39281
# 10/10 [==============================] - 0s 6ms/step - loss: 1.4408 - acc: 0.1875 - val_loss: 1.3936 - val_acc: 0.2500
# Epoch 5/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.3578 - acc: 0.5000
# Epoch 00005: val_loss did not improve from 1.39281
# 10/10 [==============================] - 0s 7ms/step - loss: 1.3997 - acc: 0.2750 - val_loss: 1.3931 - val_acc: 0.2000
# Epoch 6/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.4258 - acc: 0.0000e+00
# Epoch 00006: val_loss did not improve from 1.39281
# 10/10 [==============================] - 0s 6ms/step - loss: 1.4090 - acc: 0.1750 - val_loss: 1.4006 - val_acc: 0.2500
# Epoch 7/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.3939 - acc: 0.2500
# Epoch 00007: val_loss did not improve from 1.39281
# 10/10 [==============================] - 0s 6ms/step - loss: 1.4013 - acc: 0.2125 - val_loss: 1.4017 - val_acc: 0.2000
# Epoch 8/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.3420 - acc: 0.3750
# Epoch 00008: val_loss did not improve from 1.39281
# 10/10 [==============================] - 0s 6ms/step - loss: 1.3944 - acc: 0.2750 - val_loss: 1.3950 - val_acc: 0.2000
# Epoch 9/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.3387 - acc: 0.5000
# Epoch 00009: val_loss improved from 1.39281 to 1.39109, saving model to models\Best
# 10/10 [==============================] - 0s 8ms/step - loss: 1.3878 - acc: 0.2875 - val_loss: 1.3911 - val_acc: 0.2500
# Epoch 10/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.3706 - acc: 0.3750
# Epoch 00010: val_loss did not improve from 1.39109
# 10/10 [==============================] - 0s 6ms/step - loss: 1.3945 - acc: 0.2875 - val_loss: 1.3929 - val_acc: 0.2000
# Epoch 11/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.4214 - acc: 0.1250
# Epoch 00011: val_loss did not improve from 1.39109
# 10/10 [==============================] - 0s 6ms/step - loss: 1.3870 - acc: 0.2375 - val_loss: 1.4047 - val_acc: 0.2500
# Epoch 12/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.3652 - acc: 0.3750
# Epoch 00012: val_loss did not improve from 1.39109
# 10/10 [==============================] - 0s 7ms/step - loss: 1.3951 - acc: 0.2375 - val_loss: 1.4094 - val_acc: 0.2500
# Epoch 13/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.3689 - acc: 0.2500
# Epoch 00013: val_loss did not improve from 1.39109
# 10/10 [==============================] - 0s 6ms/step - loss: 1.3851 - acc: 0.3125 - val_loss: 1.4165 - val_acc: 0.2500
# Epoch 14/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.2378 - acc: 0.5000
# Epoch 00014: val_loss improved from 1.39109 to 1.39053, saving model to models\Best
# 10/10 [==============================] - 0s 8ms/step - loss: 1.3748 - acc: 0.2875 - val_loss: 1.3905 - val_acc: 0.2500
# Epoch 15/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.3478 - acc: 0.3750
# Epoch 00015: val_loss did not improve from 1.39053
# 10/10 [==============================] - 0s 8ms/step - loss: 1.3695 - acc: 0.2875 - val_loss: 1.4007 - val_acc: 0.2500
# Epoch 16/200
#  9/10 [==========================>...] - ETA: 0s - loss: 1
# Epoch 00027: val_loss did not improve from 1.39053
# 10/10 [==============================] - 0s 6ms/step - loss: 1.3655 - acc: 0.2625 - val_loss: 1.4090 - val_acc: 0.2000
# Epoch 28/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.3739 - acc: 0.2500
# Epoch 00028: val_loss did not improve from 1.39053
# 10/10 [==============================] - 0s 6ms/step - loss: 1.3650 - acc: 0.3750 - val_loss: 1.4099 - val_acc: 0.2000
# Epoch 29/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.2695 - acc: 0.6250
# Epoch 00029: val_loss did not improve from 1.39053
# 10/10 [==============================] - 0s 6ms/step - loss: 1.3611 - acc: 0.3250 - val_loss: 1.4200 - val_acc: 0.2500
# Epoch 30/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.3666 - acc: 0.6250
# Epoch 00030: val_loss did not improve from 1.39053
# 10/10 [==============================] - 0s 7ms/step - loss: 1.3449 - acc: 0.3750 - val_loss: 1.4478 - val_acc: 0.2500
# Epoch 31/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.4926 - acc: 0.0000e+00
# Epoch 00031: val_loss did not improve from 1.39053
# 10/10 [==============================] - 0s 6ms/step - loss: 1.3777 - acc: 0.2625 - val_loss: 1.4283 - val_acc: 0.2000
# Epoch 32/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.2888 - acc: 0.2500
# Epoch 00032: val_loss did not improve from 1.39053
# 10/10 [==============================] - 0s 6ms/step - loss: 1.3582 - acc: 0.2750 - val_loss: 1.4194 - val_acc: 0.1500
# Epoch 33/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.4826 - acc: 0.1250
# Epoch 00033: val_loss did not improve from 1.39053
# 10/10 [==============================] - 0s 6ms/step - loss: 1.3700 - acc: 0.3250 - val_loss: 1.4276 - val_acc: 0.2000
# Epoch 34/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.3429 - acc: 0.2500
# Epoch 00034: val_loss did not improve from 1.39053
# 10/10 [==============================] - 0s 6ms/step - loss: 1.3764 - acc: 0.2875 - val_loss: 1.4305 - val_acc: 0.2000
# Epoch 35/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.3738 - acc: 0.2500
# Epoch 00035: val_loss did not improve from 1.39053
# 10/10 [==============================] - 0s 6ms/step - loss: 1.3510 - acc: 0.3000 - val_loss: 1.4157 - val_acc: 0.2500
# Epoch 36/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.3921 - acc: 0.3750
# Epoch 00036: val_loss did not improve from 1.39053
# 10/10 [==============================] - 0s 7ms/step - loss: 1.3767 - acc: 0.2750 - val_loss: 1.4120 - val_acc: 0.2500
# Epoch 37/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.2898 - acc: 0.2500
# Epoch 00037: val_loss did not improve from 1.39053
# 10/10 [==============================] - 0s 8ms/step - loss: 1.3631 - acc: 0.3250 - val_loss: 1.4256 - val_acc: 0.2500
# Epoch 38/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.2057 - acc: 0.6250
# Epoch 00038: val_loss did not improve from 1.39053
# 10/10 [==============================] - 0s 7ms/step - loss: 1.3661 - acc: 0.3625 - val_loss: 1.4305 - val_acc: 0.2000
# Epoch 39/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.4472 - acc: 0.1250
# Epoch 00039: val_loss did not improve from 1.39053
# 10/10 [==============================] - 0s 6ms/step - loss: 1.3716 - acc: 0.2875 - val_loss: 1.4520 - val_acc: 0.2500
# Epoch 40/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.4332 - acc: 0.1250
# Epoch 00040: val_loss did not improve from 1.39053
# 10/10 [==============================] - 0s 6ms/step - loss: 1.3559 - acc: 0.3500 - val_loss: 1.4180 - val_acc: 0.2500
# Epoch 41/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.3986 - acc: 0.3750
# Epoch 00041: val_loss did not improve from 1.39053
# 10/10 [==============================] - 0s 7ms/step - loss: 1.3640 - acc: 0.3500 - val_loss: 1.4238 - val_acc: 0.3000
# Epoch 42/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.3600 - acc: 0.5000
# Epoch 00042: val_loss did not improve from 1.39053
# 10/10 [==============================] - 0s 6ms/step - loss: 1.3359 - acc: 0.4125 - val_loss: 1.4280 - val_acc: 0.2500
# Epoch 43/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.2428 - acc: 0.5000
# Epoch 00043: val_loss did not improve from 1.39053
# 10/10 [==============================] - 0s 7ms/step - loss: 1.3485 - acc: 0.3250 - val_loss: 1.4348 - val_acc: 0.1500
# Epoch 44/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.3870 - acc: 0.2500
# Epoch 00044: val_loss did not improve from 1.39053
# 10/10 [==============================] - 0s 7ms/step - loss: 1.3725 - acc: 0.3375 - val_loss: 1.4290 - val_acc: 0.2500
# Epoch 45/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.3490 - acc: 0.3750
# Epoch 00045: val_loss did not improve from 1.39053
# 10/10 [==============================] - 0s 6ms/step - loss: 1.3409 - acc: 0.3000 - val_loss: 1.4277 - val_acc: 0.3000
# Epoch 46/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.3172 - acc: 0.3750
# Epoch 00046: val_loss did not improve from 1.39053
# 10/10 [==============================] - 0s 7ms/step - loss: 1.3353 - acc: 0.3625 - val_loss: 1.4407 - val_acc: 0.1500
# Epoch 47/200
#  7/10 [====================>.........] - ETA: 0s - loss: 1.3499 - acc: 0.2500
# Epoch 00047: val_loss did not improve from 1.39053
# 10/10 [==============================] - 0s 9ms/step - loss: 1.3411 - acc: 0.2875 - val_loss: 1.4264 - val_acc: 0.2000
# Epoch 48/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.3653 - acc: 0.2500
# Epoch 00048: val_loss did not improve from 1.39053
# 10/10 [==============================] - 0s 6ms/step - loss: 1.3791 - acc: 0.3250 - val_loss: 1.4440 - val_acc: 0.1500
# Epoch 49/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.3319 - acc: 0.3750
# Epoch 00049: val_loss did not improve from 1.39053
# 10/10 [==============================] - 0s 6ms/step - loss: 1.3290 - acc: 0.3625 - val_loss: 1.4345 - val_acc: 0.2500
# Epoch 50/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.2923 - acc: 0.3750
# Epoch 00050: val_loss did not improve from 1.39053
# 10/10 [==============================] - 0s 6ms/step - loss: 1.3633 - acc: 0.2750 - val_loss: 1.4267 - val_acc: 0.2000
# Epoch 51/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.2917 - acc: 0.5000
# Epoch 00051: val_loss did not improve from 1.39053
# 10/10 [==============================] - 0s 7ms/step - loss: 1.3247 - acc: 0.3875 - val_loss: 1.4153 - val_acc: 0.3500
# Epoch 52/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.3174 - acc: 0.3750
# Epoch 00052: val_loss did not improve from 1.39053
# 10/10 [==============================] - 0s 6ms/step - loss: 1.3631 - acc: 0.3750 - val_loss: 1.4466 - val_acc: 0.1500
# Epoch 53/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.2956 - acc: 0.3750
# Epoch 00053: val_loss did not improve from 1.39053
# 10/10 [==============================] - 0s 6ms/step - loss: 1.3394 - acc: 0.2875 - val_loss: 1.4317 - val_acc: 0.2000
# Epoch 54/200
#  1/10 [==>...........................] - ETA: 0s - loss: 1.2975 - acc: 0.3750
# Epoch 00054: val_loss did not improve from 1.39053
# 10/10 [==============================] - 0s 7ms/step - loss: 1.3273 - acc: 0.3250 - val_loss: 1.4318 - val_acc: 0.2000

# %%
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss for EEG LSTM')
plt.ylabel('Loss value')
plt.xlabel('# epoch')
plt.legend(loc="upper left")
plt.show()

# %%
plt.plot(history.history['acc'], label='Training Acc')
plt.plot(history.history['val_acc'], label='Validation Acc')
plt.title('Acc for EEG LSTM')
plt.ylabel('Acc value')
plt.xlabel('# epoch')
plt.legend(loc="upper left")
plt.show()

# %%
model.load_weights(f"models\Best")

# %%
train_x.shape
# Out:
# (337, 12, 128)

# %%
pred = model.predict(train_x[0].reshape(-1, train_x.shape[1], train_x.shape[2]))

# %%
pred
# Out:
# array([[3.3189676e-04, 4.2085871e-03, 6.9821896e-03, 2.4181621e-03,
#         2.3798265e-04, 2.1329962e-03, 5.0884534e-02, 6.4253420e-02,
#         8.6855030e-01]], dtype=float32)

# %%
np.argmax(pred)
# Out:
# 8

# %%
train_y[:10]
# Out:
# array([8, 7, 1, 2, 1, 1, 6, 1, 3, 7])

# %%
model.save_weights('models\model.h5')
model_json = model.to_json()
with open('models\model.json', "w") as json_file:
    json_file.write(model_json)
