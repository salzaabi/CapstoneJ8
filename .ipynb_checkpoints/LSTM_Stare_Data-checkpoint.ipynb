# %% [markdown]
# <h1> Imports

# %%
import pandas as pd
import numpy as np
import os
from matplotlib import pyplot as plt 
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectFdr
from scipy.signal import butter, lfilter, filtfilt, freqz
from scipy import signal

# %% [markdown]
# <h1> Fitlering Functions

# %%
from joblib import dump, load

def pca_and_inverse(df, val=False, retain=0.95):
    if not val:
        print("Fit and save PCA")
        pca = PCA(retain).fit(df)
        dump(pca, 'models\\pca')
    else:
        print("Load PCA")
        pca = load('models\\pca')
    components = pca.transform(df)
    return pca.inverse_transform(components)

# %%
record_export_folder = 'recordings'
# keep_cols = ['EEG.P7', 'EEG.O1', 'EEG.O2', 'EEG.P8'] # ['Timestamp', 'EEG.Counter', 'EEG.P7', 'EEG.O1', 'EEG.O2', 'EEG.P8']
keep_cols = ["O1/theta","O1/alpha","O1/betaL","O1/betaH","O1/gamma",
             "O2/theta","O2/alpha","O2/betaL","O2/betaH","O2/gamma"]
keep_cols = ["O1/betaL","O1/betaH",
             "O2/betaL","O2/betaH"]

def load_df(file_name):
    file_path = os.path.join(record_export_folder, file_name)
    return pd.read_csv(file_path, skiprows=0, header=0)

def trim_cols(df):
    return df[keep_cols]

# %% [markdown]
# <h1> Data from 4 Sensors

# %%
df = trim_cols(load_df('psychopy_sultan_recording_{}.csv'.format(0)))

# %%
subplot = 0
fig, axs = plt.subplots(10)
for col in df.columns:
    axs[subplot].plot(df[col].values)
    subplot += 1

# %%
pca_df = pca_and_inverse(df[:480])
subplot = 0
fig, axs = plt.subplots(10)
for col in range(pca_df.shape[1]):
    axs[subplot].plot(pca_df[:,col])
    subplot += 1
# Out:
# Fit and save PCA

# %%
pca_df = pca_and_inverse(df[480:], True)
subplot = 0
fig, axs = plt.subplots(10)
for col in range(pca_df.shape[1]):
    axs[subplot].plot(pca_df[:,col])
    subplot += 1
# Out:
# Load PCA

# %% [markdown]
# <h1> Training Data

# %%
from sklearn.preprocessing import minmax_scale

# %%
seconds_to_check = 3
total_data_points = 600
interval_range = int(8 * seconds_to_check)
data_points = int(total_data_points / interval_range)

def split_to_training_data(df):
    total_data = []
    for interval_start in range(0, len(df), interval_range):
        temp_data = []
        for col in range(0, df.shape[1]):
            temp_data.append(df[interval_start:interval_start + interval_range, col])
        
        total_data.append(temp_data)
        
    return np.asarray(total_data)

def create_target_data(data, target):
    return np.asarray([target] * data.shape[0])

def create_target_data_by_size(size, target):
    return np.asarray([target] * size)
    
def scale_and_normalize(data):
    print(data.shape)
    for sample in range(data.shape[0]):
        for col in range(data.shape[1]):
            data[sample,col,:] = minmax_scale(data[sample,col,:])
#         for feature in range(data.shape[1]):
#             data[sample,feature,:] = minmax_scale(data[sample,feature,:])
#             data[:,col] = minmax_scale(data[:,col])
    return data
#     return minmax_scale(data)

# %%
targets = range(0, 4)
total_train_x = []
total_validate_x = []
total_train_y = []
total_validate_y = []
for target in targets:
    df = trim_cols(load_df('psychopy_sultan_recording_{}.csv'.format(target)))
    total_data = np.asarray(df.values)
    
    
    labels = create_target_data_by_size(data_points, target)
    train_y = labels[:20]
    validation_y = labels[20:]
    
    
    train_x = total_data[:480]
    validation_x = total_data[480:]
    
    
    if target == targets[0]:
        total_train_x = train_x
        total_validate_x = validation_x
        total_train_y = train_y
        total_validate_y = validation_y
    else:
        total_train_x = np.concatenate((total_train_x, train_x))
        total_validate_x = np.concatenate((total_validate_x, validation_x))
        total_train_y = np.concatenate((total_train_y, train_y))
        total_validate_y = np.concatenate((total_validate_y, validation_y))

# %%
# total_train_x = pca_and_inverse(total_train_x, False, 0.9)
# total_validate_x = pca_and_inverse(total_validate_x, True)

total_train_x = split_to_training_data(total_train_x)
total_validate_x = split_to_training_data(total_validate_x)
    
total_train_x = scale_and_normalize(total_train_x)
total_validate_x = scale_and_normalize(total_validate_x)
    
#     train_x = scale_and_normalize(train_x)
# Out:
# (80, 4, 24)
# (20, 4, 24)

# %%
total_train_x.shape
# Out:
# (80, 4, 24)

# %%
total_train_y.shape
# Out:
# (80,)

# %%
np.mean(total_train_x[0,0,:])
# Out:
# 0.44756309834638824

# %%
# train_x, validation_x, train_y, validation_y = train_test_split(total_train_x, total_train_y, test_size = 0.20)

# %%
train_x = total_train_x
validation_x = total_validate_x

# average each second of data instead of the whole 3 sec segment
# train_x = train_x.reshape(80,4,3,8)
# validation_x = validation_x.reshape(20,4,3,8)
# train_x = np.mean(train_x, axis=3)
# validation_x = np.mean(validation_x, axis=3)

# train_x = np.mean(total_train_x, axis=2)
# validation_x = np.mean(total_validate_x, axis=2)
train_y = total_train_y
validation_y = total_validate_y

# %%
# double the data set
# train_x = np.concatenate((train_x, train_x))
# validation_x = np.concatenate((validation_x, validation_x))
# train_y = np.concatenate((train_y, train_y))
# validation_y = np.concatenate((validation_y, validation_y))

# %%
train_x.shape
# Out:
# (80, 4, 24)

# %%
validation_x.shape
# Out:
# (20, 4, 24)

# %%
train_y.shape
# Out:
# (80,)

# %%
validation_y.shape
# Out:
# (20,)

# %%
# train_x, validation_x, train_y, validation_y = train_test_split(total_train_x, total_train_y, test_size = 0.20)

# %%
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import SGD, Adam, Adamax, RMSprop, Adagrad
from tensorflow.keras.models import Sequential
from tensorflow.keras import regularizers
from tensorflow.keras.layers import Flatten, Dense, Dropout, LSTM, SimpleRNN, GRU, BatchNormalization, LayerNormalization, ActivityRegularization
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau, EarlyStopping

# %%
def create_model_dense():
    model = Sequential()
    model.add(Flatten())
    model.add(Dense(16, activation='relu', activity_regularizer = regularizers.l2(l2 = 0.001)))
    model.add(Dropout(0.6))
#     model.add(ActivityRegularization(l2=0.001))
    
    model.add(Dense(16, activation='relu', activity_regularizer = regularizers.l2(l2 = 0.001)))
    model.add(Dropout(0.6))
    
#     model.add(Dense(8, activation='relu', activity_regularizer = regularizers.l2(l2 = 0.001)))
#     model.add(Dropout(0.1))
#     model.add(ActivityRegularization(l2=0.001))

    model.add(Dense(4, activation="softmax"))
    
    return model

# %%
def create_model():
    model = Sequential()
    model.add(LSTM(100, input_shape=(train_x.shape[1:]), return_sequences=True))
    model.add(Dropout(0.5))
    model.add(ActivityRegularization(l2=0.001))

    model.add(LSTM(10, input_shape=(train_x.shape[1:]), return_sequences=False))
    model.add(Dropout(0.5))

#     model.add(Dense(16))

    model.add(Dense(4, activation="softmax"))
    
    return model

# %%
EPOCHS = 200
BATCH_SIZE = 8
NAME= "models\BEST"

# %%
model = create_model_dense()
    
opt = tf.keras.optimizers.Adam(0.01)

model.compile(loss='sparse_categorical_crossentropy',
              optimizer=opt, metrics=['acc'])

callbacks = [
#     TensorBoard(f"logs\LSTM-{int(time.time())}"),
    ReduceLROnPlateau(patience=25, factor=0.9),
#     EarlyStopping(patience=40),
#     ModelCheckpoint(filepath=f"models\Best", monitor='val_loss', verbose=2, save_weights_only=True, save_best_only=True, mode='min')
]
    
history = model.fit(train_x,
                    train_y,
                    batch_size= BATCH_SIZE,
                    epochs = EPOCHS,
                    validation_data=(validation_x, validation_y), 
                    callbacks=callbacks)
# Out:
# Epoch 1/200
# 10/10 [==============================] - 0s 18ms/step - loss: 1.5440 - acc: 0.2500 - val_loss: 1.3845 - val_acc: 0.2000
# Epoch 2/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.4359 - acc: 0.2750 - val_loss: 1.3679 - val_acc: 0.4000
# Epoch 3/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.4248 - acc: 0.3125 - val_loss: 1.3844 - val_acc: 0.4000
# Epoch 4/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.4109 - acc: 0.2750 - val_loss: 1.3843 - val_acc: 0.2500
# Epoch 5/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.4105 - acc: 0.2000 - val_loss: 1.3813 - val_acc: 0.2500
# Epoch 6/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3837 - acc: 0.2250 - val_loss: 1.3839 - val_acc: 0.2500
# Epoch 7/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3824 - acc: 0.3125 - val_loss: 1.3833 - val_acc: 0.3500
# Epoch 8/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3809 - acc: 0.3250 - val_loss: 1.3837 - val_acc: 0.2500
# Epoch 9/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3946 - acc: 0.2625 - val_loss: 1.3853 - val_acc: 0.2000
# Epoch 10/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3956 - acc: 0.2500 - val_loss: 1.3849 - val_acc: 0.2500
# Epoch 11/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3735 - acc: 0.3250 - val_loss: 1.3794 - val_acc: 0.4000
# Epoch 12/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3785 - acc: 0.2750 - val_loss: 1.3696 - val_acc: 0.4500
# Epoch 13/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3566 - acc: 0.3625 - val_loss: 1.3658 - val_acc: 0.2500
# Epoch 14/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3751 - acc: 0.2875 - val_loss: 1.3844 - val_acc: 0.2000
# Epoch 15/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.4025 - acc: 0.2250 - val_loss: 1.3960 - val_acc: 0.2000
# Epoch 16/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3951 - acc: 0.3000 - val_loss: 1.3822 - val_acc: 0.3500
# Epoch 17/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3884 - acc: 0.2375 - val_loss: 1.3813 - val_acc: 0.3000
# Epoch 18/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3667 - acc: 0.3250 - val_loss: 1.3832 - val_acc: 0.2500
# Epoch 19/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3471 - acc: 0.2750 - val_loss: 1.3947 - val_acc: 0.3500
# Epoch 20/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.4301 - acc: 0.2250 - val_loss: 1.3867 - val_acc: 0.2000
# Epoch 21/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3630 - acc: 0.2375 - val_loss: 1.3842 - val_acc: 0.3500
# Epoch 22/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3580 - acc: 0.2750 - val_loss: 1.3884 - val_acc: 0.2500
# Epoch 23/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3604 - acc: 0.3250 - val_loss: 1.3794 - val_acc: 0.3500
# Epoch 24/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3361 - acc: 0.3500 - val_loss: 1.3798 - val_acc: 0.3000
# Epoch 25/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3541 - acc: 0.3750 - val_loss: 1.3881 - val_acc: 0.2500
# Epoch 26/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3443 - acc: 0.3125 - val_loss: 1.3799 - val_acc: 0.3000
# Epoch 27/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3595 - acc: 0.3000 - val_loss: 1.3803 - val_acc: 0.3500
# Epoch 28/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3652 - acc: 0.3375 - val_loss: 1.3861 - val_acc: 0.3000
# Epoch 29/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3565 - acc: 0.2875 - val_loss: 1.3898 - val_acc: 0.2500
# Epoch 30/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3961 - acc: 0.2500 - val_loss: 1.3877 - val_acc: 0.3000
# Epoch 31/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3669 - acc: 0.2750 - val_loss: 1.3954 - val_acc: 0.2000
# Epoch 32/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3540 - acc: 0.3500 - val_loss: 1.3961 - val_acc: 0.3000
# Epoch 33/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3757 - acc: 0.2750 - val_loss: 1.3893 - val_acc: 0.3000
# Epoch 34/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3380 - acc: 0.3125 - val_loss: 1.3980 - val_acc: 0.3000
# Epoch 35/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3441 - acc: 0.3375 - val_loss: 1.3957 - val_acc: 0.3000
# Epoch 36/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3612 - acc: 0.2625 - val_loss: 1.3938 - val_acc: 0.3500
# Epoch 37/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3693 - acc: 0.3375 - val_loss: 1.3808 - val_acc: 0.3500
# Epoch 38/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3540 - acc: 0.3125 - val_loss: 1.3842 - val_acc: 0.2000
# Epoch 39/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.2967 - acc: 0.3000 - val_loss: 1.3982 - val_acc: 0.3000
# Epoch 40/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3547 - acc: 0.2500 - val_loss: 1.4077 - val_acc: 0.2500
# Epoch 41/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3183 - acc: 0.2250 - val_loss: 1.3953 - val_acc: 0.1500
# Epoch 42/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3514 - acc: 0.2625 - val_loss: 1.3860 - val_acc: 0.1500
# Epoch 43/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3529 - acc: 0.2000 - val_loss: 1.3948 - val_acc: 0.3000
# Epoch 44/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3529 - acc: 0.3250 - val_loss: 1.3981 - val_acc: 0.4500
# Epoch 45/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3648 - acc: 0.2250 - val_loss: 1.3956 - val_acc: 0.3500
# Epoch 46/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3079 - acc: 0.3750 - val_loss: 1.3931 - val_acc: 0.4000
# Epoch 47/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3290 - acc: 0.2750 - val_loss: 1.3918 - val_acc: 0.3000
# Epoch 48/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3239 - acc: 0.3000 - val_loss: 1.4025 - val_acc: 0.2000
# Epoch 49/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3362 - acc: 0.3000 - val_loss: 1.3927 - val_acc: 0.2000
# Epoch 50/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.2495 - acc: 0.3750 - val_loss: 1.3977 - val_acc: 0.3500
# Epoch 51/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3406 - acc: 0.3000 - val_loss: 1.4057 - val_acc: 0.3000
# Epoch 52/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3625 - acc: 0.2875 - val_loss: 1.4110 - val_acc: 0.2500
# Epoch 53/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3099 - acc: 0.3375 - val_loss: 1.4142 - val_acc: 0.5000
# Epoch 54/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3106 - acc: 0.3375 - val_loss: 1.3909 - val_acc: 0.2500
# Epoch 55/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3912 - acc: 0.2500 - val_loss: 1.3842 - val_acc: 0.2500
# Epoch 56/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3517 - acc: 0.2875 - val_loss: 1.3837 - val_acc: 0.2500
# Epoch 57/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3419 - acc: 0.2875 - val_loss: 1.3993 - val_acc: 0.2500
# Epoch 58/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3614 - acc: 0.2625 - val_loss: 1.4005 - val_acc: 0.2000
# Epoch 59/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.2532 - acc: 0.4125 - val_loss: 1.3752 - val_acc: 0.4500
# Epoch 60/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.4512 - acc: 0.3250 - val_loss: 1.3832 - val_acc: 0.3000
# Epoch 61/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3153 - acc: 0.3000 - val_loss: 1.3773 - val_acc: 0.3000
# Epoch 62/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3546 - acc: 0.2500 - val_loss: 1.3849 - val_acc: 0.2000
# Epoch 63/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3525 - acc: 0.3250 - val_loss: 1.4013 - val_acc: 0.2000
# Epoch 64/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3361 - acc: 0.2875 - val_loss: 1.3954 - val_acc: 0.3500
# Epoch 65/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.2864 - acc: 0.3375 - val_loss: 1.3869 - val_acc: 0.3500
# Epoch 66/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3673 - acc: 0.2625 - val_loss: 1.3991 - val_acc: 0.3500
# Epoch 67/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3039 - acc: 0.2750 - val_loss: 1.4128 - val_acc: 0.2500
# Epoch 68/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3123 - acc: 0.3000 - val_loss: 1.3976 - val_acc: 0.3000
# Epoch 69/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.2423 - acc: 0.3750 - val_loss: 1.4093 - val_acc: 0.2500
# Epoch 70/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3988 - acc: 0.2500 - val_loss: 1.3823 - val_acc: 0.3500
# Epoch 71/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3295 - acc: 0.3000 - val_loss: 1.3715 - val_acc: 0.3000
# Epoch 72/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3470 - acc: 0.3000 - val_loss: 1.3722 - val_acc: 0.3000
# Epoch 73/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.2759 - acc: 0.3500 - val_loss: 1.3836 - val_acc: 0.2000
# Epoch 74/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.2913 - acc: 0.3500 - val_loss: 1.3866 - val_acc: 0.2500
# Epoch 75/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.2867 - acc: 0.3625 - val_loss: 1.3856 - val_acc: 0.2000
# Epoch 76/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3677 - acc: 0.2875 - val_loss: 1.3793 - val_acc: 0.2000
# Epoch 77/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.2996 - acc: 0.3250 - val_loss: 1.3947 - val_acc: 0.2000
# Epoch 78/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3107 - acc: 0.3125 - val_loss: 1.3961 - val_acc: 0.2500
# Epoch 79/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.2891 - acc: 0.3500 - val_loss: 1.3817 - val_acc: 0.3500
# Epoch 80/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3347 - acc: 0.2875 - val_loss: 1.3885 - val_acc: 0.2500
# Epoch 81/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3236 - acc: 0.3125 - val_loss: 1.3780 - val_acc: 0.2500
# Epoch 82/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3160 - acc: 0.3250 - val_loss: 1.3858 - val_acc: 0.3500
# Epoch 83/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3308 - acc: 0.3000 - val_loss: 1.3955 - val_acc: 0.3500
# Epoch 84/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3829 - acc: 0.2750 - val_loss: 1.3836 - val_acc: 0.3500
# Epoch 85/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3327 - acc: 0.3125 - val_loss: 1.3769 - val_acc: 0.2500
# Epoch 86/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3380 - acc: 0.3250 - val_loss: 1.4167 - val_acc: 0.2000
# Epoch 87/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3361 - acc: 0.3250 - val_loss: 1.4703 - val_acc: 0.3000
# Epoch 88/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3297 - acc: 0.3125 - val_loss: 1.3782 - val_acc: 0.3500
# Epoch 89/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3091 - acc: 0.3250 - val_loss: 1.3681 - val_acc: 0.4000
# Epoch 90/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3192 - acc: 0.3250 - val_loss: 1.3652 - val_acc: 0.4000
# Epoch 91/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3138 - acc: 0.3125 - val_loss: 1.3785 - val_acc: 0.3000
# Epoch 92/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.2859 - acc: 0.3375 - val_loss: 1.3896 - val_acc: 0.2500
# Epoch 93/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3182 - acc: 0.3000 - val_loss: 1.3965 - val_acc: 0.2500
# Epoch 94/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.2802 - acc: 0.3250 - val_loss: 1.4494 - val_acc: 0.2000
# Epoch 95/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3191 - acc: 0.3000 - val_loss: 1.4044 - val_acc: 0.2500
# Epoch 96/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3233 - acc: 0.3125 - val_loss: 1.3842 - val_acc: 0.4000
# Epoch 97/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3237 - acc: 0.3125 - val_loss: 1.3884 - val_acc: 0.3500
# Epoch 98/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.2810 - acc: 0.3375 - val_loss: 1.3962 - val_acc: 0.3000
# Epoch 99/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3189 - acc: 0.3125 - val_loss: 1.3754 - val_acc: 0.4500
# Epoch 100/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3002 - acc: 0.3500 - val_loss: 1.3959 - val_acc: 0.3500
# Epoch 101/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3226 - acc: 0.3250 - val_loss: 1.3933 - val_acc: 0.3500
# Epoch 102/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.2943 - acc: 0.3500 - val_loss: 1.3668 - val_acc: 0.5000
# Epoch 103/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.2768 - acc: 0.3000 - val_loss: 1.3875 - val_acc: 0.3500
# Epoch 104/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3479 - acc: 0.2875 - val_loss: 1.3956 - val_acc: 0.2000
# Epoch 105/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.2917 - acc: 0.3375 - val_loss: 1.4083 - val_acc: 0.2500
# Epoch 106/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3314 - acc: 0.2875 - val_loss: 1.4217 - val_acc: 0.3500
# Epoch 107/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3791 - acc: 0.3000 - val_loss: 1.3715 - val_acc: 0.2500
# Epoch 108/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3509 - acc: 0.3000 - val_loss: 1.3767 - val_acc: 0.2500
# Epoch 109/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3625 - acc: 0.2750 - val_loss: 1.3788 - val_acc: 0.3000
# Epoch 110/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3355 - acc: 0.2875 - val_loss: 1.3625 - val_acc: 0.2500
# Epoch 111/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3495 - acc: 0.2875 - val_loss: 1.3645 - val_acc: 0.2500
# Epoch 112/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3568 - acc: 0.2750 - val_loss: 1.3726 - val_acc: 0.2500
# Epoch 113/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3362 - acc: 0.2625 - val_loss: 1.3696 - val_acc: 0.2500
# Epoch 114/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3355 - acc: 0.3000 - val_loss: 1.3763 - val_acc: 0.2000
# Epoch 115/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3420 - acc: 0.3000 - val_loss: 1.3665 - val_acc: 0.2500
# Epoch 116/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3357 - acc: 0.3000 - val_loss: 1.3806 - val_acc: 0.3000
# Epoch 117/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3471 - acc: 0.2750 - val_loss: 1.3721 - val_acc: 0.3000
# Epoch 118/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3594 - acc: 0.2875 - val_loss: 1.3475 - val_acc: 0.3500
# Epoch 119/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3372 - acc: 0.2875 - val_loss: 1.3442 - val_acc: 0.3500
# Epoch 120/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3427 - acc: 0.2875 - val_loss: 1.3470 - val_acc: 0.3500
# Epoch 121/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3497 - acc: 0.2125 - val_loss: 1.3520 - val_acc: 0.2000
# Epoch 122/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3732 - acc: 0.2500 - val_loss: 1.3626 - val_acc: 0.2500
# Epoch 123/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.2852 - acc: 0.3500 - val_loss: 1.4095 - val_acc: 0.2000
# Epoch 124/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3088 - acc: 0.3125 - val_loss: 1.4079 - val_acc: 0.2000
# Epoch 125/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3379 - acc: 0.2500 - val_loss: 1.3863 - val_acc: 0.2000
# Epoch 126/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3588 - acc: 0.2375 - val_loss: 1.3834 - val_acc: 0.2000
# Epoch 127/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3366 - acc: 0.2875 - val_loss: 1.3828 - val_acc: 0.2000
# Epoch 128/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3532 - acc: 0.2750 - val_loss: 1.3709 - val_acc: 0.2500
# Epoch 129/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3402 - acc: 0.3000 - val_loss: 1.3770 - val_acc: 0.2500
# Epoch 130/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3514 - acc: 0.2750 - val_loss: 1.3915 - val_acc: 0.2000
# Epoch 131/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3619 - acc: 0.2000 - val_loss: 1.3823 - val_acc: 0.2500
# Epoch 132/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3197 - acc: 0.2875 - val_loss: 1.3694 - val_acc: 0.3000
# Epoch 133/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3517 - acc: 0.2875 - val_loss: 1.3655 - val_acc: 0.3000
# Epoch 134/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3304 - acc: 0.3125 - val_loss: 1.3903 - val_acc: 0.2500
# Epoch 135/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3089 - acc: 0.3000 - val_loss: 1.3701 - val_acc: 0.2500
# Epoch 136/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3125 - acc: 0.2750 - val_loss: 1.3686 - val_acc: 0.2500
# Epoch 137/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3166 - acc: 0.2875 - val_loss: 1.3909 - val_acc: 0.2000
# Epoch 138/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3296 - acc: 0.2875 - val_loss: 1.3914 - val_acc: 0.2500
# Epoch 139/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3222 - acc: 0.3000 - val_loss: 1.3868 - val_acc: 0.2500
# Epoch 140/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3756 - acc: 0.2625 - val_loss: 1.3632 - val_acc: 0.3000
# Epoch 141/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3444 - acc: 0.2875 - val_loss: 1.3613 - val_acc: 0.3000
# Epoch 142/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3083 - acc: 0.3125 - val_loss: 1.3686 - val_acc: 0.3000
# Epoch 143/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3242 - acc: 0.3000 - val_loss: 1.3951 - val_acc: 0.2000
# Epoch 144/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3251 - acc: 0.2500 - val_loss: 1.3940 - val_acc: 0.2000
# Epoch 145/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3368 - acc: 0.2500 - val_loss: 1.3678 - val_acc: 0.3000
# Epoch 146/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3382 - acc: 0.2500 - val_loss: 1.3714 - val_acc: 0.2500
# Epoch 147/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3162 - acc: 0.3125 - val_loss: 1.3960 - val_acc: 0.2500
# Epoch 148/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3377 - acc: 0.2250 - val_loss: 1.3789 - val_acc: 0.3000
# Epoch 149/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.2962 - acc: 0.2875 - val_loss: 1.3744 - val_acc: 0.2500
# Epoch 150/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3333 - acc: 0.3000 - val_loss: 1.3586 - val_acc: 0.3000
# Epoch 151/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3524 - acc: 0.2750 - val_loss: 1.3636 - val_acc: 0.2500
# Epoch 152/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3326 - acc: 0.2875 - val_loss: 1.3672 - val_acc: 0.2500
# Epoch 153/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3041 - acc: 0.2500 - val_loss: 1.3829 - val_acc: 0.3000
# Epoch 154/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3484 - acc: 0.2000 - val_loss: 1.3878 - val_acc: 0.2500
# Epoch 155/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3746 - acc: 0.2500 - val_loss: 1.3652 - val_acc: 0.2500
# Epoch 156/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3758 - acc: 0.2500 - val_loss: 1.3650 - val_acc: 0.2500
# Epoch 157/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3421 - acc: 0.2875 - val_loss: 1.3611 - val_acc: 0.2500
# Epoch 158/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3503 - acc: 0.2750 - val_loss: 1.3533 - val_acc: 0.3000
# Epoch 159/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3220 - acc: 0.2750 - val_loss: 1.3950 - val_acc: 0.3000
# Epoch 160/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3279 - acc: 0.2250 - val_loss: 1.4160 - val_acc: 0.3500
# Epoch 161/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3436 - acc: 0.2625 - val_loss: 1.3692 - val_acc: 0.2500
# Epoch 162/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3231 - acc: 0.2750 - val_loss: 1.3526 - val_acc: 0.3500
# Epoch 163/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3357 - acc: 0.2375 - val_loss: 1.3778 - val_acc: 0.2500
# Epoch 164/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3219 - acc: 0.2625 - val_loss: 1.3915 - val_acc: 0.3500
# Epoch 165/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3889 - acc: 0.2625 - val_loss: 1.3543 - val_acc: 0.3500
# Epoch 166/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3510 - acc: 0.2000 - val_loss: 1.3577 - val_acc: 0.2500
# Epoch 167/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3159 - acc: 0.2750 - val_loss: 1.3738 - val_acc: 0.2000
# Epoch 168/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3359 - acc: 0.3000 - val_loss: 1.3830 - val_acc: 0.2000
# Epoch 169/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3359 - acc: 0.2875 - val_loss: 1.3781 - val_acc: 0.2000
# Epoch 170/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3285 - acc: 0.2500 - val_loss: 1.3707 - val_acc: 0.2500
# Epoch 171/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3217 - acc: 0.2250 - val_loss: 1.3659 - val_acc: 0.2000
# Epoch 172/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3534 - acc: 0.2750 - val_loss: 1.3529 - val_acc: 0.3000
# Epoch 173/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3368 - acc: 0.3000 - val_loss: 1.3519 - val_acc: 0.3000
# Epoch 174/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3463 - acc: 0.2750 - val_loss: 1.3602 - val_acc: 0.3000
# Epoch 175/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3219 - acc: 0.3125 - val_loss: 1.3617 - val_acc: 0.3000
# Epoch 176/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3145 - acc: 0.2750 - val_loss: 1.3681 - val_acc: 0.2500
# Epoch 177/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3390 - acc: 0.2875 - val_loss: 1.3680 - val_acc: 0.2500
# Epoch 178/200
# 10/10 [==============================] - ETA: 0s - loss: 1.4075 - acc: 0.250 - 0s 4ms/step - loss: 1.3451 - acc: 0.2625 - val_loss: 1.3596 - val_acc: 0.3000
# Epoch 179/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3476 - acc: 0.2250 - val_loss: 1.3686 - val_acc: 0.2500
# Epoch 180/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3627 - acc: 0.2750 - val_loss: 1.3887 - val_acc: 0.2500
# Epoch 181/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3079 - acc: 0.2125 - val_loss: 1.4129 - val_acc: 0.1500
# Epoch 182/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3680 - acc: 0.2750 - val_loss: 1.4468 - val_acc: 0.1500
# Epoch 183/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3453 - acc: 0.2875 - val_loss: 1.3656 - val_acc: 0.2500
# Epoch 184/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3144 - acc: 0.2375 - val_loss: 1.3594 - val_acc: 0.2500
# Epoch 185/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3448 - acc: 0.2625 - val_loss: 1.3590 - val_acc: 0.2500
# Epoch 186/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3338 - acc: 0.3000 - val_loss: 1.3614 - val_acc: 0.2500
# Epoch 187/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3400 - acc: 0.2375 - val_loss: 1.3695 - val_acc: 0.2500
# Epoch 188/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3384 - acc: 0.2875 - val_loss: 1.3709 - val_acc: 0.2000
# Epoch 189/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3596 - acc: 0.2750 - val_loss: 1.3645 - val_acc: 0.2500
# Epoch 190/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3609 - acc: 0.2750 - val_loss: 1.3576 - val_acc: 0.3000
# Epoch 191/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3278 - acc: 0.2000 - val_loss: 1.3597 - val_acc: 0.3000
# Epoch 192/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3454 - acc: 0.3125 - val_loss: 1.3631 - val_acc: 0.3000
# Epoch 193/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3301 - acc: 0.2500 - val_loss: 1.3563 - val_acc: 0.3000
# Epoch 194/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3356 - acc: 0.3250 - val_loss: 1.3575 - val_acc: 0.2500
# Epoch 195/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3348 - acc: 0.3500 - val_loss: 1.3597 - val_acc: 0.2500
# Epoch 196/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3181 - acc: 0.2375 - val_loss: 1.3634 - val_acc: 0.3000
# Epoch 197/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3193 - acc: 0.2875 - val_loss: 1.3655 - val_acc: 0.2500
# Epoch 198/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3171 - acc: 0.2750 - val_loss: 1.3654 - val_acc: 0.2500
# Epoch 199/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3332 - acc: 0.2750 - val_loss: 1.3598 - val_acc: 0.3000
# Epoch 200/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3599 - acc: 0.2750 - val_loss: 1.3600 - val_acc: 0.3000

# %%
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss for EEG LSTM')
plt.ylabel('Loss value')
plt.xlabel('# epoch')
plt.legend(loc="upper left")
plt.show()

# %%
plt.plot(history.history['acc'], label='Training Acc')
plt.plot(history.history['val_acc'], label='Validation Acc')
plt.title('Acc for EEG LSTM')
plt.ylabel('Acc value')
plt.xlabel('# epoch')
plt.legend(loc="upper left")
plt.show()

# %%
model.load_weights(f"models\Best")

# %%
train_x.shape
# Out:
# (337, 12, 128)

# %%
pred = model.predict(train_x[0].reshape(-1, train_x.shape[1], train_x.shape[2]))

# %%
pred
# Out:
# array([[3.3189676e-04, 4.2085871e-03, 6.9821896e-03, 2.4181621e-03,
#         2.3798265e-04, 2.1329962e-03, 5.0884534e-02, 6.4253420e-02,
#         8.6855030e-01]], dtype=float32)

# %%
np.argmax(pred)
# Out:
# 8

# %%
train_y[:10]
# Out:
# array([8, 7, 1, 2, 1, 1, 6, 1, 3, 7])

# %%
model.save_weights('models\model.h5')
model_json = model.to_json()
with open('models\model.json', "w") as json_file:
    json_file.write(model_json)
