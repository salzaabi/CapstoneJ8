# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt 
from scipy import signal
from sklearn.cross_decomposition import CCA
from scipy.signal import kaiserord, lfilter, firwin, freqz, butter, filtfilt, convolve
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

# %% [markdown]
# ## Load Dataset

# %%
# theta     -> 4-8 Hz
# alpha     -> 8-12 Hz
# low beta  -> 12-16 Hz
# high beta -> 16-25 Hz
# gamma     -> 25-45 Hz
# our freqs: 15 (betaL), 12 (alpha/betaL), 8.57 (alpha), 5.45 (theta)

dataset_name = "recordings/psychopy_sultan_recording_" # 0 to 3
num_targets = 4
targets = [None] * num_targets
channels = ['O1/theta', 'O1/alpha', 'O1/betaL', 'O1/betaH', 'O1/gamma', 'O2/theta', 'O2/alpha', 'O2/betaL', 'O2/betaH', 'O2/gamma'] # data channels
for i in range(num_targets):
    targets[i] = pd.read_csv(dataset_name+str(i)+'.csv')
    targets[i]['Unnamed: 0'] = [i % 8 for i in range(len(targets[i].index))]
    targets[i].rename(columns = {'Unnamed: 0': 'Counter'}, inplace=True)
targets[0].head
# Out:
# <bound method NDFrame.head of      Counter  O1/theta  O1/alpha  O1/betaL  O1/betaH  O1/gamma  O2/theta  \
# 0          0     0.598     0.750     0.959     0.850     0.640     0.630
# 1          1     0.725     0.918     1.052     0.883     0.582     0.568
# 2          2     0.809     1.082     1.081     0.868     0.529     0.494
# 3          3     0.808     1.178     1.037     0.801     0.489     0.415
# 4          4     0.721     1.161     0.937     0.695     0.466     0.354
# ..       ...       ...       ...       ...       ...       ...       ...
# 595        3     0.299     0.428     0.171     0.174     0.184     0.091
# 596        4     0.357     0.420     0.189     0.184     0.190     0.090
# 597        5     0.406     0.452     0.198     0.197     0.196     0.095
# 598        6     0.433     0.521     0.195     0.206     0.205     0.106
# 599        7     0.427     0.611     0.186     0.215     0.217     0.124
#
#      O2/alpha  O2/betaL  O2/betaH  O2/gamma          TIME
# 0       0.540     0.099     0.244     0.518  1.606229e+09
# 1       0.481     0.095     0.225     0.488  1.606229e+09
# 2       0.476     0.122     0.219     0.470  1.606229e+09
# 3       0.515     0.172     0.218     0.452  1.606229e+09
# 4       0.587     0.233     0.218     0.427  1.606229e+09
# ..        ...       ...       ...       ...           ...
# 595     0.802     0.633     0.155     0.105  1.606229e+09
# 596     0.839     0.612     0.164     0.108  1.606229e+09
# 597     0.905     0.534     0.179     0.113  1.606229e+09
# 598     1.005     0.431     0.197     0.119  1.606229e+09
# 599     1.110     0.335     0.213     0.129  1.606229e+09
#
# [600 rows x 12 columns]>

# %%
def cut_uneven_datasets(df_list):
    # use this function if the datasets are of uneven length - chop to minimum df size
    cutoff_list = [len(df_list[i].index) for i in range(num_targets)]
    cutoff = min(cutoff_list)
    for i in range(len(cutoff_list)):
        keep_indicies = set(range(df_list[i].shape[0])) - set(range(cutoff, df_list[i].shape[0]))
        df_list[i] = df_list[i].take(list(keep_indicies))
        # make sure each df same length
        print('new length of dataset {} = {}'.format(i+1, len(df_list[i].index)))
    return df_list
        
# check size - make sure each target is the same length
for i in range(num_targets):
    print('length target {} = {}'.format(i, len(targets[i].index)))

# fix length
# targets = cut_uneven_datasets(targets)
# Out:
# length target 0 = 600
# length target 1 = 600
# length target 2 = 600
# length target 3 = 600

# %%
# copy unfiltered data
original_data = [None] * num_targets
for i in range(num_targets):
    original_data[i] = pd.read_csv(dataset_name+str(i)+'.csv')
    original_data[i]['Unnamed: 0'] = [i % 120 for i in range(len(original_data[i].index))]
    original_data[i].rename(columns = {'Unnamed: 0': 'Counter'}, inplace=True)

# %%
# plot power bands over time
def plot_bands(targets, start=0, end=600):
    names = ['theta', 'alpha', 'betaL', 'betaH', 'gamma']
    for i in range(num_targets):
        fig1, ax1 = plt.subplots(figsize=(10, 5))
        fig2, ax2 = plt.subplots(figsize=(10, 5))
        for channel in channels:
            if 'O1' in channel:
                a = ax1
                ch = 'O1'
            elif 'O2' in channel:
                a = ax2
                ch = 'O2'
            targets[i][channel][start:end].plot(y=channel, grid=True, ax=a, title='Target {} {} Power Bands Over Time'.format(i, ch))
            a.legend(names)

# %%
plot_bands(targets)

# %%
# find channel with highest value in each 1s period (or 2s, 3s?)
def find_max_powers(targets, num_seconds=1):
    o1_channels = ['O1/theta', 'O1/alpha', 'O1/betaL', 'O1/betaH', 'O1/gamma'] 
    o2_channels = ['O2/theta', 'O2/alpha', 'O2/betaL', 'O2/betaH', 'O2/gamma']
    # targets - list of df's
    # sampling freq of 8 per second
    num_chunks = len(targets[0].index) // (8 * num_seconds)
    chunk = 0
    stop_row = len(targets[0].index)
    for i in range(num_targets):
        row = 0
        while True:
            if row >= stop_row or stop_row - row < 8 * num_seconds:
                break
            o1_data = np.asarray(targets[i][o1_channels][row:row+8*num_seconds])
            o2_data = np.asarray(targets[i][o2_channels][row:row+8*num_seconds])
            # which channel has highest average value?
            # do for o1 and o2
            # average
            o1_avgs = o1_data.mean(axis=0)
            o2_avgs = o2_data.mean(axis=0)
            
            print(o1_avgs)
            print(o2_avgs)
            
            max1_o1 = np.argmax(o1_avgs)
            o1_avgs[max1_o1] = 0
            max2_o1 = np.argmax(o1_avgs)
            max1_o2 = np.argmax(o2_avgs)
            o2_avgs[max1_o2] = 0
            max2_o2 = np.argmax(o2_avgs)
            o1_sel = [o1_channels[max1_o1], o1_channels[max2_o1]]
            o2_sel = [o2_channels[max1_o2], o2_channels[max2_o2]]
            
            # print('o1', o1_avgs, '\n')
            # print('o2', o2_avgs, '\n')
            
            print('target {} row {} prediction'.format(i, row))
            print('o1 -> {}'.format(o1_sel))
            print('o2 -> {}\n'.format(o2_sel))
        
            
            chunk += 1
            row += 8 * num_seconds

# %%
find_max_powers(targets)
# Out:
# [0.636125 0.99275  0.904375 0.695    0.50575 ]
# [0.439375 0.610125 0.207875 0.224375 0.426875]
# target 0 row 0 prediction
# o1 -> ['O1/alpha', 'O1/betaL']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.416375 1.6405   0.415375 0.555125 0.42775 ]
# [0.3325   0.6105   0.2945   0.400375 0.194375]
# target 0 row 8 prediction
# o1 -> ['O1/alpha', 'O1/betaH']
# o2 -> ['O2/alpha', 'O2/betaH']
#
# [0.40925 0.91775 0.65375 0.78125 0.46675]
# [0.401375 0.579    0.478    0.358125 0.19    ]
# target 0 row 16 prediction
# o1 -> ['O1/alpha', 'O1/betaH']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.497625 1.203125 0.5055   0.5075   0.607   ]
# [0.50425 0.276   0.16475 0.20975 0.201  ]
# target 0 row 24 prediction
# o1 -> ['O1/alpha', 'O1/gamma']
# o2 -> ['O2/theta', 'O2/alpha']
#
# [0.18825  1.023125 0.2735   0.57925  0.670125]
# [0.2755   0.267    0.212    0.261625 0.281125]
# target 0 row 32 prediction
# o1 -> ['O1/alpha', 'O1/gamma']
# o2 -> ['O2/gamma', 'O2/theta']
#
# [0.256375 0.349    0.385125 0.770625 0.564625]
# [0.1975   0.22575  0.34175  0.33625  0.142375]
# target 0 row 40 prediction
# o1 -> ['O1/betaH', 'O1/gamma']
# o2 -> ['O2/betaL', 'O2/betaH']
#
# [0.4105   1.136875 0.303125 0.410375 0.674   ]
# [0.9385   0.745875 0.536375 0.184625 0.204   ]
# target 0 row 48 prediction
# o1 -> ['O1/alpha', 'O1/gamma']
# o2 -> ['O2/theta', 'O2/alpha']
#
# [0.462125 1.039875 0.6625   0.416625 0.501375]
# [0.499    0.87925  0.3585   0.2595   0.268875]
# target 0 row 56 prediction
# o1 -> ['O1/alpha', 'O1/betaL']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.255875 0.44725  0.65     0.3555   0.558375]
# [0.149125 0.347    0.3435   0.209625 0.336375]
# target 0 row 64 prediction
# o1 -> ['O1/betaL', 'O1/gamma']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.346875 0.8655   0.97075  0.366125 0.463375]
# [0.47575  1.632625 0.406375 0.19175  0.197   ]
# target 0 row 72 prediction
# o1 -> ['O1/betaL', 'O1/alpha']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.20525  0.712125 0.6275   0.551    0.62675 ]
# [0.125875 0.216    0.192875 0.10725  0.399625]
# target 0 row 80 prediction
# o1 -> ['O1/alpha', 'O1/betaL']
# o2 -> ['O2/gamma', 'O2/alpha']
#
# [0.23275  0.805875 0.714375 0.719375 0.731875]
# [0.0855   0.239125 0.51175  0.252625 0.26475 ]
# target 0 row 88 prediction
# o1 -> ['O1/alpha', 'O1/gamma']
# o2 -> ['O2/betaL', 'O2/gamma']
#
# [0.47875  0.604625 0.659125 0.4525   0.40025 ]
# [0.265125 0.828625 0.76475  0.3055   0.22175 ]
# target 0 row 96 prediction
# o1 -> ['O1/betaL', 'O1/alpha']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.362    0.598    0.433625 0.322    0.57925 ]
# [0.2315   0.935875 0.78875  0.26325  0.2315  ]
# target 0 row 104 prediction
# o1 -> ['O1/alpha', 'O1/gamma']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.565375 0.379    0.77775  0.588375 0.678875]
# [0.265375 0.30825  0.512375 0.301625 0.187625]
# target 0 row 112 prediction
# o1 -> ['O1/betaL', 'O1/gamma']
# o2 -> ['O2/betaL', 'O2/alpha']
#
# [0.64025  0.5575   0.695375 0.455875 0.396625]
# [0.412375 0.2505   0.247625 0.162875 0.09725 ]
# target 0 row 120 prediction
# o1 -> ['O1/betaL', 'O1/theta']
# o2 -> ['O2/theta', 'O2/alpha']
#
# [0.7025  0.64725 0.4065  0.36075 0.49675]
# [0.3005   0.34     0.15275  0.129125 0.165625]
# target 0 row 128 prediction
# o1 -> ['O1/theta', 'O1/alpha']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.6545   0.486    0.146    0.2345   0.405625]
# [0.250625 0.417875 0.286125 0.168    0.14575 ]
# target 0 row 136 prediction
# o1 -> ['O1/theta', 'O1/alpha']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.43825  0.410125 0.349375 0.4025   0.50725 ]
# [0.42275  0.340875 0.24425  0.293125 0.185375]
# target 0 row 144 prediction
# o1 -> ['O1/gamma', 'O1/theta']
# o2 -> ['O2/theta', 'O2/alpha']
#
# [0.294125 0.32125  0.442125 0.698    0.561375]
# [0.419375 0.243625 0.29325  0.312625 0.242   ]
# target 0 row 152 prediction
# o1 -> ['O1/betaH', 'O1/gamma']
# o2 -> ['O2/theta', 'O2/betaH']
#
# [0.41325  0.76675  0.619625 0.632875 0.787625]
# [0.315125 0.781    0.48275  0.238125 0.311875]
# target 0 row 160 prediction
# o1 -> ['O1/gamma', 'O1/alpha']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.444125 0.33625  0.419125 0.506375 0.5615  ]
# [0.363375 0.58375  0.48025  0.242125 0.189125]
# target 0 row 168 prediction
# o1 -> ['O1/gamma', 'O1/betaH']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.231125 0.373625 0.366    0.6485   0.644625]
# [0.24625 0.247   0.23475 0.369   0.308  ]
# target 0 row 176 prediction
# o1 -> ['O1/betaH', 'O1/gamma']
# o2 -> ['O2/betaH', 'O2/gamma']
#
# [0.313    0.881125 0.859875 0.308125 0.485125]
# [0.337875 0.522375 0.55     0.222625 0.272625]
# target 0 row 184 prediction
# o1 -> ['O1/alpha', 'O1/betaL']
# o2 -> ['O2/betaL', 'O2/alpha']
#
# [0.397625 0.624375 0.214125 0.441    0.576875]
# [0.3615   0.54025  0.249125 0.159    0.1785  ]
# target 0 row 192 prediction
# o1 -> ['O1/alpha', 'O1/gamma']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.317375 0.9315   0.16925  0.293875 0.42925 ]
# [0.187375 1.00275  0.1595   0.156125 0.210875]
# target 0 row 200 prediction
# o1 -> ['O1/alpha', 'O1/gamma']
# o2 -> ['O2/alpha', 'O2/gamma']
#
# [0.526875 1.024    0.33675  0.5475   0.379625]
# [0.3945   0.922125 0.46975  0.256625 0.30575 ]
# target 0 row 208 prediction
# o1 -> ['O1/alpha', 'O1/betaH']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.244625 0.90225  0.425125 0.49425  0.657625]
# [0.262625 0.48225  0.46575  0.278    0.402125]
# target 0 row 216 prediction
# o1 -> ['O1/alpha', 'O1/gamma']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.177875 0.633375 0.561875 0.42075  0.479375]
# [0.208625 0.391125 0.3795   0.17925  0.2065  ]
# target 0 row 224 prediction
# o1 -> ['O1/alpha', 'O1/betaL']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.2835   0.313125 0.55     0.659625 0.5865  ]
# [0.1685   0.266625 0.2345   0.210625 0.17425 ]
# target 0 row 232 prediction
# o1 -> ['O1/betaH', 'O1/gamma']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.3415   0.373875 0.229875 0.391625 0.301125]
# [0.358375 0.454    0.222875 0.232125 0.247375]
# target 0 row 240 prediction
# o1 -> ['O1/betaH', 'O1/alpha']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.198    0.34375  0.403375 0.668    0.52025 ]
# [0.254125 0.320125 0.51975  0.46075  0.2835  ]
# target 0 row 248 prediction
# o1 -> ['O1/betaH', 'O1/gamma']
# o2 -> ['O2/betaL', 'O2/betaH']
#
# [0.25     0.245875 0.257375 0.427875 0.699125]
# [0.148625 0.19925  0.49125  0.444625 0.2805  ]
# target 0 row 256 prediction
# o1 -> ['O1/gamma', 'O1/betaH']
# o2 -> ['O2/betaL', 'O2/betaH']
#
# [0.203    0.61175  0.36475  0.298375 0.34825 ]
# [0.367375 0.59675  0.447125 0.154875 0.1255  ]
# target 0 row 264 prediction
# o1 -> ['O1/alpha', 'O1/betaL']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.346    0.40225  0.35275  0.333625 0.4105  ]
# [0.3495   0.353875 0.30175  0.1725   0.2105  ]
# target 0 row 272 prediction
# o1 -> ['O1/gamma', 'O1/alpha']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.376375 0.773375 0.6725   0.794    0.71025 ]
# [0.32175  0.652125 0.632125 0.45475  0.35025 ]
# target 0 row 280 prediction
# o1 -> ['O1/betaH', 'O1/alpha']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.1555   0.287875 0.238    0.359375 0.37325 ]
# [0.21375  0.1255   0.185875 0.2105   0.10175 ]
# target 0 row 288 prediction
# o1 -> ['O1/gamma', 'O1/betaH']
# o2 -> ['O2/theta', 'O2/betaH']
#
# [0.187    0.712375 0.43775  0.475625 0.392875]
# [0.25525  0.6555   0.225125 0.2825   0.2155  ]
# target 0 row 296 prediction
# o1 -> ['O1/alpha', 'O1/betaH']
# o2 -> ['O2/alpha', 'O2/betaH']
#
# [0.348125 0.81075  0.235375 0.355    0.565125]
# [0.30275  0.813    0.16225  0.2135   0.297625]
# target 0 row 304 prediction
# o1 -> ['O1/alpha', 'O1/gamma']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.691125 1.10575  0.597125 0.24675  0.37275 ]
# [0.427875 0.82825  0.570625 0.210625 0.186125]
# target 0 row 312 prediction
# o1 -> ['O1/alpha', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.4255   0.385375 0.4425   0.28725  0.224   ]
# [0.324375 0.463125 0.456125 0.2365   0.1835  ]
# target 0 row 320 prediction
# o1 -> ['O1/betaL', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.315625 0.620375 0.2765   0.23975  0.2765  ]
# [0.172625 0.60075  0.218    0.19525  0.170875]
# target 0 row 328 prediction
# o1 -> ['O1/alpha', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.136125 0.314125 0.20675  0.286    0.238375]
# [0.147875 0.278875 0.220875 0.29     0.164625]
# target 0 row 336 prediction
# o1 -> ['O1/alpha', 'O1/betaH']
# o2 -> ['O2/betaH', 'O2/alpha']
#
# [0.218875 0.265625 0.358    0.214125 0.40425 ]
# [0.230625 0.2395   0.301125 0.169625 0.17525 ]
# target 0 row 344 prediction
# o1 -> ['O1/gamma', 'O1/betaL']
# o2 -> ['O2/betaL', 'O2/alpha']
#
# [0.41275  0.595125 0.388625 0.241125 0.449375]
# [0.514125 0.529375 0.54475  0.207    0.19175 ]
# target 0 row 352 prediction
# o1 -> ['O1/alpha', 'O1/gamma']
# o2 -> ['O2/betaL', 'O2/alpha']
#
# [0.576125 0.75425  0.299375 0.557125 0.424   ]
# [0.237125 0.475875 0.11775  0.22075  0.172875]
# target 0 row 360 prediction
# o1 -> ['O1/alpha', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.40925  0.37325  0.356375 0.3505   0.506   ]
# [0.37525  0.886375 0.202875 0.191125 0.220625]
# target 0 row 368 prediction
# o1 -> ['O1/gamma', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.1985   0.470375 0.371625 0.2965   0.380375]
# [0.41875  0.788625 0.456875 0.30375  0.148   ]
# target 0 row 376 prediction
# o1 -> ['O1/alpha', 'O1/gamma']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.298125 0.168375 0.343    0.456625 0.2955  ]
# [0.445    0.26075  0.209875 0.251    0.1885  ]
# target 0 row 384 prediction
# o1 -> ['O1/betaH', 'O1/betaL']
# o2 -> ['O2/theta', 'O2/alpha']
#
# [0.2625   0.257375 0.275375 0.3075   0.1775  ]
# [0.191625 0.1875   0.240375 0.157    0.08525 ]
# target 0 row 392 prediction
# o1 -> ['O1/betaH', 'O1/betaL']
# o2 -> ['O2/betaL', 'O2/theta']
#
# [0.4035   0.33075  0.20825  0.341125 0.15025 ]
# [0.213    0.171375 0.138625 0.14925  0.059375]
# target 0 row 400 prediction
# o1 -> ['O1/theta', 'O1/betaH']
# o2 -> ['O2/theta', 'O2/alpha']
#
# [0.448625 1.112125 0.37025  0.54825  0.32375 ]
# [0.193625 0.912625 0.304875 0.274    0.180375]
# target 0 row 408 prediction
# o1 -> ['O1/alpha', 'O1/betaH']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.419    1.011125 0.387125 0.635    0.379125]
# [0.244875 0.60375  0.2085   0.383    0.18075 ]
# target 0 row 416 prediction
# o1 -> ['O1/alpha', 'O1/betaH']
# o2 -> ['O2/alpha', 'O2/betaH']
#
# [0.416125 0.531375 0.578875 0.502875 0.250375]
# [0.374875 0.431625 0.344875 0.1715   0.14075 ]
# target 0 row 424 prediction
# o1 -> ['O1/betaL', 'O1/alpha']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.378    0.722625 0.235875 0.2295   0.236125]
# [0.288375 0.996875 0.213125 0.1315   0.107625]
# target 0 row 432 prediction
# o1 -> ['O1/alpha', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.36925  1.136625 0.328    0.299375 0.283625]
# [0.254875 0.891375 0.299    0.241625 0.11625 ]
# target 0 row 440 prediction
# o1 -> ['O1/alpha', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.519125 1.074875 0.55075  0.37025  0.22425 ]
# [0.204625 0.53875  0.353375 0.229125 0.10125 ]
# target 0 row 448 prediction
# o1 -> ['O1/alpha', 'O1/betaL']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.670875 0.305125 0.501625 0.257625 0.236875]
# [0.5735   0.739    0.69275  0.295125 0.17075 ]
# target 0 row 456 prediction
# o1 -> ['O1/theta', 'O1/betaL']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.354625 0.354875 0.364625 0.252    0.194375]
# [0.25725  0.348625 0.47575  0.13025  0.166   ]
# target 0 row 464 prediction
# o1 -> ['O1/betaL', 'O1/alpha']
# o2 -> ['O2/betaL', 'O2/alpha']
#
# [0.2965   0.482875 0.301375 0.259625 0.1615  ]
# [0.161125 0.6495   0.37475  0.201625 0.1125  ]
# target 0 row 472 prediction
# o1 -> ['O1/alpha', 'O1/betaL']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.61675  0.460625 0.218    0.477625 0.495   ]
# [0.49425  0.450875 0.26975  0.33625  0.268625]
# target 0 row 480 prediction
# o1 -> ['O1/theta', 'O1/gamma']
# o2 -> ['O2/theta', 'O2/alpha']
#
# [0.4825   0.32225  0.688    0.41125  0.550125]
# [0.283625 0.577375 0.406125 0.305875 0.136625]
# target 0 row 488 prediction
# o1 -> ['O1/betaL', 'O1/gamma']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.265625 0.212375 0.349    0.257875 0.359   ]
# [0.152625 0.421875 0.403625 0.156125 0.10475 ]
# target 0 row 496 prediction
# o1 -> ['O1/gamma', 'O1/betaL']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.382875 0.3135   0.370875 0.281875 0.23175 ]
# [0.10925  0.2595   0.157125 0.132125 0.12075 ]
# target 0 row 504 prediction
# o1 -> ['O1/theta', 'O1/betaL']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.2385  0.74275 0.3525  0.37775 0.12725]
# [0.152125 0.38125  0.132625 0.28725  0.128625]
# target 0 row 512 prediction
# o1 -> ['O1/alpha', 'O1/betaH']
# o2 -> ['O2/alpha', 'O2/betaH']
#
# [0.4995   0.428875 0.23125  0.26425  0.185375]
# [0.443625 0.398375 0.288375 0.262    0.15975 ]
# target 0 row 520 prediction
# o1 -> ['O1/theta', 'O1/alpha']
# o2 -> ['O2/theta', 'O2/alpha']
#
# [0.295    0.390125 0.35925  0.19825  0.17775 ]
# [0.492375 0.543375 0.319875 0.164    0.173625]
# target 0 row 528 prediction
# o1 -> ['O1/alpha', 'O1/betaL']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.281625 0.734    0.5485   0.2715   0.161   ]
# [0.221    1.385    0.64375  0.167625 0.130875]
# target 0 row 536 prediction
# o1 -> ['O1/alpha', 'O1/betaL']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.508875 0.348375 0.479875 0.308    0.371875]
# [0.279875 0.518    0.37625  0.153    0.20575 ]
# target 0 row 544 prediction
# o1 -> ['O1/theta', 'O1/betaL']
# o2 -> ['O2/alpha', 'O2/betaL']
# [0.324    0.718625 0.302625 0.218875 0.210875]
# [0.1805   0.314125 0.26125  0.13225  0.1475  ]
# target 0 row 552 prediction
# o1 -> ['O1/alpha', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.369625 0.23175  0.211375 0.216125 0.149625]
# [0.298375 0.218625 0.1725   0.128    0.147625]
# target 0 row 560 prediction
# o1 -> ['O1/theta', 'O1/alpha']
# o2 -> ['O2/theta', 'O2/alpha']
#
# [0.330625 0.30375  0.142875 0.2765   0.28725 ]
# [0.250625 0.13075  0.1915   0.14975  0.13525 ]
# target 0 row 568 prediction
# o1 -> ['O1/theta', 'O1/alpha']
# o2 -> ['O2/theta', 'O2/betaL']
#
# [0.495875 1.14525  0.33425  0.26125  0.2105  ]
# [0.50975  1.288625 0.547    0.197875 0.136125]
# target 0 row 576 prediction
# o1 -> ['O1/alpha', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.306625 0.451625 0.218875 0.187    0.164375]
# [0.273375 0.4845   0.215    0.138625 0.09575 ]
# target 0 row 584 prediction
# o1 -> ['O1/alpha', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.31875  0.48975  0.167125 0.1875   0.1895  ]
# [0.099375 0.845125 0.493125 0.168125 0.109375]
# target 0 row 592 prediction
# o1 -> ['O1/alpha', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [1.131875 1.245    1.154875 0.614875 0.490875]
# [0.787875 0.76075  1.038    0.40975  0.311125]
# target 1 row 0 prediction
# o1 -> ['O1/alpha', 'O1/betaL']
# o2 -> ['O2/betaL', 'O2/theta']
#
# [0.53525  0.626375 0.463875 0.3925   0.2965  ]
# [0.397125 0.613375 0.423625 0.276375 0.160625]
# target 1 row 8 prediction
# o1 -> ['O1/alpha', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.438125 0.454    0.4      0.370875 0.276   ]
# [0.35425  0.3055   0.53075  0.301625 0.2205  ]
# target 1 row 16 prediction
# o1 -> ['O1/alpha', 'O1/theta']
# o2 -> ['O2/betaL', 'O2/theta']
#
# [0.420375 0.8095   0.13525  0.499    0.310625]
# [0.593    0.7385   0.207625 0.302625 0.148375]
# target 1 row 24 prediction
# o1 -> ['O1/alpha', 'O1/betaH']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.38025  0.751625 0.3315   0.276125 0.49125 ]
# [0.45325  0.741    0.248875 0.2175   0.1705  ]
# target 1 row 32 prediction
# o1 -> ['O1/alpha', 'O1/gamma']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.38275  0.966375 0.263625 0.37625  0.646   ]
# [0.475    0.400875 0.2155   0.155875 0.222375]
# target 1 row 40 prediction
# o1 -> ['O1/alpha', 'O1/gamma']
# o2 -> ['O2/theta', 'O2/alpha']
#
# [0.44775  0.179125 0.601375 0.62525  0.950625]
# [0.332875 0.567125 0.376625 0.394    0.6075  ]
# target 1 row 48 prediction
# o1 -> ['O1/gamma', 'O1/betaH']
# o2 -> ['O2/gamma', 'O2/alpha']
#
# [0.336    0.475875 0.287875 0.584125 0.53725 ]
# [0.206375 0.591125 0.599875 0.296375 0.204125]
# target 1 row 56 prediction
# o1 -> ['O1/betaH', 'O1/gamma']
# o2 -> ['O2/betaL', 'O2/alpha']
#
# [0.420875 0.6245   0.18375  0.453125 0.397375]
# [0.250875 0.235    0.386375 0.165875 0.1645  ]
# target 1 row 64 prediction
# o1 -> ['O1/alpha', 'O1/betaH']
# o2 -> ['O2/betaL', 'O2/theta']
#
# [0.3705   0.43225  0.34875  0.321625 0.617625]
# [0.29225 0.37925 0.63075 0.16625 0.209  ]
# target 1 row 72 prediction
# o1 -> ['O1/gamma', 'O1/alpha']
# o2 -> ['O2/betaL', 'O2/alpha']
#
# [0.272375 0.897875 0.434125 0.939    0.7755  ]
# [0.31625  0.42425  0.57825  0.301375 0.360875]
# target 1 row 80 prediction
# o1 -> ['O1/betaH', 'O1/alpha']
# o2 -> ['O2/betaL', 'O2/alpha']
#
# [0.434    1.80975  1.430625 0.643    0.451875]
# [0.413375 1.069    0.781125 0.321125 0.266375]
# target 1 row 88 prediction
# o1 -> ['O1/alpha', 'O1/betaL']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.992375 1.747125 0.74725  0.75475  0.73975 ]
# [0.604    0.433875 0.4945   0.21825  0.229   ]
# target 1 row 96 prediction
# o1 -> ['O1/alpha', 'O1/theta']
# o2 -> ['O2/theta', 'O2/betaL']
#
# [1.10025  1.20975  0.67925  0.464625 0.434125]
# [0.640125 1.21575  0.635125 0.156125 0.280125]
# target 1 row 104 prediction
# o1 -> ['O1/alpha', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [2.041625 0.730875 0.644875 0.4425   0.45325 ]
# [1.0405   0.748875 0.536    0.23025  0.220375]
# target 1 row 112 prediction
# o1 -> ['O1/theta', 'O1/alpha']
# o2 -> ['O2/theta', 'O2/alpha']
#
# [0.1975   0.413    0.464625 0.458375 0.383   ]
# [0.225125 0.264125 0.27225  0.280625 0.1395  ]
# target 1 row 120 prediction
# o1 -> ['O1/betaL', 'O1/betaH']
# o2 -> ['O2/betaH', 'O2/betaL']
#
# [0.286875 1.098875 0.87075  0.45425  0.556125]
# [0.25     0.65275  0.550625 0.204875 0.158   ]
# target 1 row 128 prediction
# o1 -> ['O1/alpha', 'O1/betaL']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.193625 0.68525  0.7185   0.310375 0.532875]
# [0.121375 0.26     0.191625 0.111625 0.162875]
# target 1 row 136 prediction
# o1 -> ['O1/betaL', 'O1/alpha']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.29125  0.515125 0.76775  0.355625 0.42125 ]
# [0.3405   0.332875 0.258625 0.226625 0.14675 ]
# target 1 row 144 prediction
# o1 -> ['O1/betaL', 'O1/alpha']
# o2 -> ['O2/theta', 'O2/alpha']
#
# [0.274875 0.327125 0.26975  0.46675  0.5625  ]
# [0.27225  0.229125 0.239625 0.227    0.15975 ]
# target 1 row 152 prediction
# o1 -> ['O1/gamma', 'O1/betaH']
# o2 -> ['O2/theta', 'O2/betaL']
#
# [0.177375 0.491625 0.357375 0.738875 0.569   ]
# [0.174    0.366125 0.358    0.273375 0.240625]
# target 1 row 160 prediction
# o1 -> ['O1/betaH', 'O1/gamma']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.42475  0.833875 0.51875  0.523    1.063   ]
# [0.5085   0.690375 0.500375 0.252625 0.45475 ]
# target 1 row 168 prediction
# o1 -> ['O1/gamma', 'O1/alpha']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.20075  0.187    0.336375 0.627    1.011   ]
# [0.267375 0.301375 0.336125 0.32625  0.3465  ]
# target 1 row 176 prediction
# o1 -> ['O1/gamma', 'O1/betaH']
# o2 -> ['O2/gamma', 'O2/betaL']
#
# [0.646625 0.868125 0.80775  0.6835   0.51475 ]
# [0.491   1.2005  0.712   0.24625 0.323  ]
# target 1 row 184 prediction
# o1 -> ['O1/alpha', 'O1/betaL']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.26775  1.042    0.54425  0.395375 0.60575 ]
# [0.33725  0.813875 0.426125 0.246875 0.35475 ]
# target 1 row 192 prediction
# o1 -> ['O1/alpha', 'O1/gamma']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.34925  0.70375  0.93375  0.28225  0.624625]
# [0.589375 0.409    0.314375 0.217875 0.29725 ]
# target 1 row 200 prediction
# o1 -> ['O1/betaL', 'O1/alpha']
# o2 -> ['O2/theta', 'O2/alpha']
#
# [0.280625 0.529375 0.45075  0.30475  0.4125  ]
# [0.308375 0.63525  0.228625 0.177375 0.254875]
# target 1 row 208 prediction
# o1 -> ['O1/alpha', 'O1/betaL']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.195375 0.5105   0.464625 0.565125 0.4815  ]
# [0.16125  0.510625 0.284375 0.2275   0.153125]
# target 1 row 216 prediction
# o1 -> ['O1/betaH', 'O1/alpha']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.34275  0.537875 0.2665   0.655625 0.462875]
# [0.54125 0.65875 0.20825 0.277   0.184  ]
# target 1 row 224 prediction
# o1 -> ['O1/betaH', 'O1/alpha']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.249875 0.567875 0.48625  0.497125 0.818125]
# [0.311375 1.002625 0.40275  0.315125 0.357375]
# target 1 row 232 prediction
# o1 -> ['O1/gamma', 'O1/alpha']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.324625 0.629625 0.41875  0.590375 0.542   ]
# [0.275125 0.4655   0.198375 0.11575  0.12025 ]
# target 1 row 240 prediction
# o1 -> ['O1/alpha', 'O1/betaH']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.560375 1.005875 0.344    0.24675  0.45625 ]
# [0.529875 0.858875 0.57775  0.194375 0.2465  ]
# target 1 row 248 prediction
# o1 -> ['O1/alpha', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.321    0.331875 0.75375  0.4355   0.369625]
# [0.374    0.6985   0.669125 0.267125 0.273375]
# target 1 row 256 prediction
# o1 -> ['O1/betaL', 'O1/betaH']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.31175  1.02025  0.625375 0.421    0.505125]
# [0.233125 0.93475  0.55475  0.298375 0.3095  ]
# target 1 row 264 prediction
# o1 -> ['O1/alpha', 'O1/betaL']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.221875 0.629    0.2565   0.52575  0.44675 ]
# [0.19225  0.674875 0.380625 0.3325   0.16525 ]
# target 1 row 272 prediction
# o1 -> ['O1/alpha', 'O1/betaH']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.2615   0.58975  0.229    0.5125   0.486125]
# [0.23     0.273625 0.251125 0.298625 0.174375]
# target 1 row 280 prediction
# o1 -> ['O1/alpha', 'O1/betaH']
# o2 -> ['O2/betaH', 'O2/alpha']
#
# [0.3225   0.256625 0.251375 0.3125   0.425   ]
# [0.3185   0.632875 0.4345   0.192625 0.15175 ]
# target 1 row 288 prediction
# o1 -> ['O1/gamma', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.18425  0.254375 0.358125 0.536375 0.479125]
# [0.2855   0.427625 0.426875 0.33175  0.21275 ]
# target 1 row 296 prediction
# o1 -> ['O1/betaH', 'O1/gamma']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.346125 0.435    0.598    0.398375 0.457125]
# [0.106875 0.16     0.321875 0.218625 0.193625]
# target 1 row 304 prediction
# o1 -> ['O1/betaL', 'O1/gamma']
# o2 -> ['O2/betaL', 'O2/betaH']
#
# [0.393375 1.592375 0.275125 0.402125 0.260875]
# [0.24925  0.998625 0.447625 0.20775  0.139   ]
# target 1 row 312 prediction
# o1 -> ['O1/alpha', 'O1/betaH']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.27     0.603875 0.312625 0.359    0.256375]
# [0.267375 0.253    0.354625 0.196    0.155   ]
# target 1 row 320 prediction
# o1 -> ['O1/alpha', 'O1/betaH']
# o2 -> ['O2/betaL', 'O2/theta']
#
# [0.127125 0.253    0.45025  0.386625 0.248125]
# [0.0655   0.128375 0.20125  0.182    0.1675  ]
# target 1 row 328 prediction
# o1 -> ['O1/betaL', 'O1/betaH']
# o2 -> ['O2/betaL', 'O2/betaH']
#
# [0.305375 0.668375 0.41625  0.385125 0.34475 ]
# [0.3505   0.597    0.285125 0.259875 0.1795  ]
# target 1 row 336 prediction
# o1 -> ['O1/alpha', 'O1/betaL']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.28625  0.508625 0.275375 0.302    0.365   ]
# [0.12975  0.86525  0.244625 0.183125 0.1585  ]
# target 1 row 344 prediction
# o1 -> ['O1/alpha', 'O1/gamma']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.541    0.703375 0.256875 0.285    0.63025 ]
# [0.224    0.854625 0.25175  0.2355   0.24    ]
# target 1 row 352 prediction
# o1 -> ['O1/alpha', 'O1/gamma']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.3655   0.4705   0.253875 0.4195   0.283625]
# [0.4545   0.733375 0.194625 0.372    0.2085  ]
# target 1 row 360 prediction
# o1 -> ['O1/alpha', 'O1/betaH']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.386   0.61775 0.33375 0.4035  0.28275]
# [0.3825   0.359125 0.253375 0.232875 0.209875]
# target 1 row 368 prediction
# o1 -> ['O1/alpha', 'O1/betaH']
# o2 -> ['O2/theta', 'O2/alpha']
#
# [0.4405   0.892125 0.261625 0.402625 0.29825 ]
# [0.349625 0.762875 0.36025  0.134875 0.3135  ]
# target 1 row 376 prediction
# o1 -> ['O1/alpha', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.175    0.49725  0.523    0.428875 0.477875]
# [0.3065  0.44325 0.3465  0.22    0.246  ]
# target 1 row 384 prediction
# o1 -> ['O1/betaL', 'O1/alpha']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.17925  0.40375  0.8605   0.28025  0.636125]
# [0.19325  0.21075  0.478375 0.13125  0.32675 ]
# target 1 row 392 prediction
# o1 -> ['O1/betaL', 'O1/gamma']
# o2 -> ['O2/betaL', 'O2/gamma']
#
# [0.268875 0.317125 0.57175  0.44575  0.7335  ]
# [0.293    0.38     0.324125 0.17625  0.445125]
# target 1 row 400 prediction
# o1 -> ['O1/gamma', 'O1/betaL']
# o2 -> ['O2/gamma', 'O2/alpha']
#
# [0.251375 0.50125  0.377625 0.459125 0.262125]
# [0.2725   0.397125 0.276125 0.162    0.0875  ]
# target 1 row 408 prediction
# o1 -> ['O1/alpha', 'O1/betaH']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.415    0.427375 0.45375  0.490625 0.350375]
# [0.330375 0.4405   0.177125 0.171625 0.138375]
# target 1 row 416 prediction
# o1 -> ['O1/betaH', 'O1/betaL']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.42475  0.31475  0.1735   0.541125 0.310375]
# [0.221625 0.320625 0.122875 0.202375 0.1545  ]
# target 1 row 424 prediction
# o1 -> ['O1/betaH', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.535875 0.472    0.314625 0.282125 0.217   ]
# [0.30725  0.382125 0.226375 0.154625 0.147375]
# target 1 row 432 prediction
# o1 -> ['O1/theta', 'O1/alpha']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.81075  0.386875 0.32825  0.454    0.32275 ]
# [0.635125 0.267    0.396125 0.23925  0.20525 ]
# target 1 row 440 prediction
# o1 -> ['O1/theta', 'O1/betaH']
# o2 -> ['O2/theta', 'O2/betaL']
#
# [0.36325  0.299625 0.141875 0.250625 0.432   ]
# [0.350125 0.192125 0.29725  0.114875 0.1805  ]
# target 1 row 448 prediction
# o1 -> ['O1/gamma', 'O1/theta']
# o2 -> ['O2/theta', 'O2/betaL']
#
# [0.405375 0.969625 0.3905   0.162125 0.21    ]
# [0.286375 0.7505   0.13675  0.1015   0.147875]
# target 1 row 456 prediction
# o1 -> ['O1/alpha', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.4105   0.718125 0.190125 0.114875 0.203   ]
# [0.30675  0.514625 0.127875 0.11875  0.15925 ]
# target 1 row 464 prediction
# o1 -> ['O1/alpha', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.348125 0.2295   0.230875 0.17125  0.09275 ]
# [0.185125 0.33075  0.184    0.121375 0.0825  ]
# target 1 row 472 prediction
# o1 -> ['O1/theta', 'O1/betaL']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.266875 0.30525  0.27225  0.265125 0.1485  ]
# [0.140875 0.205125 0.091    0.092125 0.0795  ]
# target 1 row 480 prediction
# o1 -> ['O1/alpha', 'O1/betaL']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.235    0.349125 0.27275  0.333125 0.3965  ]
# [0.07725  0.14175  0.205625 0.118375 0.147125]
# target 1 row 488 prediction
# o1 -> ['O1/gamma', 'O1/alpha']
# o2 -> ['O2/betaL', 'O2/gamma']
#
# [0.34675  0.3215   0.4325   0.214125 0.241375]
# [0.198    0.333375 0.130875 0.152375 0.15125 ]
# target 1 row 496 prediction
# o1 -> ['O1/betaL', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.2075   0.349125 0.554625 0.243375 0.32675 ]
# [0.157875 0.315    0.321625 0.144125 0.1055  ]
# target 1 row 504 prediction
# o1 -> ['O1/betaL', 'O1/alpha']
# o2 -> ['O2/betaL', 'O2/alpha']
#
# [0.34125  0.12425  0.106625 0.17375  0.359875]
# [0.200875 0.12625  0.086    0.085625 0.137   ]
# target 1 row 512 prediction
# o1 -> ['O1/gamma', 'O1/theta']
# o2 -> ['O2/theta', 'O2/gamma']
#
# [0.32925  0.23125  0.157    0.140375 0.374   ]
# [0.1885   0.205    0.16725  0.095875 0.2135  ]
# target 1 row 520 prediction
# o1 -> ['O1/gamma', 'O1/theta']
# o2 -> ['O2/gamma', 'O2/alpha']
#
# [0.75425  0.4645   0.264625 0.396875 0.37625 ]
# [0.4825   0.3805   0.3805   0.205375 0.16825 ]
# target 1 row 528 prediction
# o1 -> ['O1/theta', 'O1/alpha']
# o2 -> ['O2/theta', 'O2/alpha']
#
# [0.259    0.25325  0.492625 0.456    0.230375]
# [0.114125 0.13425  0.20175  0.09575  0.08175 ]
# target 1 row 536 prediction
# o1 -> ['O1/betaL', 'O1/betaH']
# o2 -> ['O2/betaL', 'O2/alpha']
#
# [0.507875 0.405    0.149125 0.17875  0.19325 ]
# [0.307125 0.354    0.252    0.06     0.104625]
# target 1 row 544 prediction
# o1 -> ['O1/theta', 'O1/alpha']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.262625 0.4805   0.297    0.28025  0.399875]
# [0.277625 0.424875 0.19925  0.117875 0.14675 ]
# target 1 row 552 prediction
# o1 -> ['O1/alpha', 'O1/gamma']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.16075  0.282625 0.29875  0.1815   0.226625]
# [0.114125 0.26225  0.205    0.054625 0.1075  ]
# target 1 row 560 prediction
# o1 -> ['O1/betaL', 'O1/alpha']
# o2 -> ['O2/alpha', 'O2/betaL']
# [0.273875 0.193125 0.142875 0.146875 0.216   ]
# [0.116    0.244875 0.14525  0.07325  0.08425 ]
# target 1 row 568 prediction
# o1 -> ['O1/theta', 'O1/gamma']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.182625 0.5      0.225625 0.293125 0.269125]
# [0.2355   0.56875  0.1535   0.14275  0.157625]
# target 1 row 576 prediction
# o1 -> ['O1/alpha', 'O1/betaH']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.37     0.253125 0.21925  0.196125 0.192625]
# [0.308625 0.177875 0.1      0.105    0.075375]
# target 1 row 584 prediction
# o1 -> ['O1/theta', 'O1/alpha']
# o2 -> ['O2/theta', 'O2/alpha']
#
# [0.374125 0.16725  0.165    0.370375 0.190125]
# [0.286625 0.23475  0.126    0.139875 0.09775 ]
# target 1 row 592 prediction
# o1 -> ['O1/theta', 'O1/betaH']
# o2 -> ['O2/theta', 'O2/alpha']
#
# [0.439625 0.41125  0.504625 0.168375 0.246625]
# [0.331125 0.55625  0.491375 0.415125 0.275375]
# target 2 row 0 prediction
# o1 -> ['O1/betaL', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [1.571125 1.0585   0.4215   0.39325  0.679375]
# [1.5065   1.311625 0.476625 1.01175  0.57075 ]
# target 2 row 8 prediction
# o1 -> ['O1/theta', 'O1/alpha']
# o2 -> ['O2/theta', 'O2/alpha']
#
# [0.772375 0.976    0.663125 0.70775  0.70575 ]
# [0.942125 0.868125 0.408125 0.52575  0.67975 ]
# target 2 row 16 prediction
# o1 -> ['O1/alpha', 'O1/theta']
# o2 -> ['O2/theta', 'O2/alpha']
#
# [0.29325  0.640375 0.79275  0.293625 0.48275 ]
# [0.247625 0.510125 0.404375 0.229625 0.25925 ]
# target 2 row 24 prediction
# o1 -> ['O1/betaL', 'O1/alpha']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.43075  0.60175  0.4715   0.378625 0.56425 ]
# [0.319125 0.664375 0.22925  0.20075  0.2615  ]
# target 2 row 32 prediction
# o1 -> ['O1/alpha', 'O1/gamma']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.49375  0.506625 0.24225  0.410375 0.44625 ]
# [0.507875 1.204625 0.2465   0.181    0.1745  ]
# target 2 row 40 prediction
# o1 -> ['O1/alpha', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.344125 0.372125 0.2605   0.292    0.39125 ]
# [0.193    0.291125 0.22525  0.133625 0.129625]
# target 2 row 48 prediction
# o1 -> ['O1/gamma', 'O1/alpha']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.19     0.411125 0.257875 0.46975  0.515375]
# [0.096875 0.276875 0.253125 0.2425   0.1515  ]
# target 2 row 56 prediction
# o1 -> ['O1/gamma', 'O1/betaH']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.26625  0.7265   0.330875 0.516    0.435   ]
# [0.268875 0.516    0.280375 0.439875 0.199375]
# target 2 row 64 prediction
# o1 -> ['O1/alpha', 'O1/betaH']
# o2 -> ['O2/alpha', 'O2/betaH']
#
# [0.3085   0.843125 0.50825  0.473125 0.60025 ]
# [0.239375 0.35375  0.1085   0.258625 0.22375 ]
# target 2 row 72 prediction
# o1 -> ['O1/alpha', 'O1/gamma']
# o2 -> ['O2/alpha', 'O2/betaH']
#
# [0.776625 1.686375 0.493375 0.4465   0.588375]
# [0.241625 0.587125 0.102875 0.301    0.211875]
# target 2 row 80 prediction
# o1 -> ['O1/alpha', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/betaH']
#
# [0.520125 1.329375 0.356625 0.729375 0.599875]
# [0.46025  1.27525  0.197875 0.352375 0.133875]
# target 2 row 88 prediction
# o1 -> ['O1/alpha', 'O1/betaH']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.19525  0.817625 0.8675   0.805125 0.550875]
# [0.186    0.9145   1.02375  0.27375  0.181875]
# target 2 row 96 prediction
# o1 -> ['O1/betaL', 'O1/alpha']
# o2 -> ['O2/betaL', 'O2/alpha']
#
# [0.5155   0.303375 0.581125 0.566    0.399875]
# [0.401125 1.04775  1.566625 0.3175   0.228125]
# target 2 row 104 prediction
# o1 -> ['O1/betaL', 'O1/betaH']
# o2 -> ['O2/betaL', 'O2/alpha']
#
# [0.458375 0.2345   0.44125  0.509    0.34775 ]
# [0.517    0.345875 0.20775  0.24625  0.2215  ]
# target 2 row 112 prediction
# o1 -> ['O1/betaH', 'O1/theta']
# o2 -> ['O2/theta', 'O2/alpha']
#
# [0.352375 0.467375 0.296875 0.44625  0.675375]
# [0.1825   0.250625 0.318    0.18125  0.21575 ]
# target 2 row 120 prediction
# o1 -> ['O1/gamma', 'O1/alpha']
# o2 -> ['O2/betaL', 'O2/alpha']
#
# [0.235125 0.67125  0.217625 0.279875 0.283875]
# [0.231   0.58725 0.23275 0.15    0.1275 ]
# target 2 row 128 prediction
# o1 -> ['O1/alpha', 'O1/gamma']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.3735   0.978875 0.199    0.548875 0.34475 ]
# [0.259    0.777625 0.239125 0.315    0.176875]
# target 2 row 136 prediction
# o1 -> ['O1/alpha', 'O1/betaH']
# o2 -> ['O2/alpha', 'O2/betaH']
#
# [0.26325  1.26825  0.49975  0.286875 0.439125]
# [0.545    0.965375 0.53825  0.25525  0.1815  ]
# target 2 row 144 prediction
# o1 -> ['O1/alpha', 'O1/betaL']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.181875 0.359625 0.272625 0.324375 0.37725 ]
# [0.588875 0.6655   0.464375 0.2895   0.263   ]
# target 2 row 152 prediction
# o1 -> ['O1/gamma', 'O1/alpha']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.41075  0.531875 0.429125 0.57075  0.30025 ]
# [0.39     0.38575  0.24875  0.339125 0.166125]
# target 2 row 160 prediction
# o1 -> ['O1/betaH', 'O1/alpha']
# o2 -> ['O2/theta', 'O2/alpha']
#
# [0.265625 0.56175  0.37675  0.308    0.6635  ]
# [0.3395   0.797875 0.3525   0.191625 0.28025 ]
# target 2 row 168 prediction
# o1 -> ['O1/gamma', 'O1/alpha']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.54525  0.524875 0.287375 0.430125 0.511875]
# [0.443125 0.434    0.173375 0.27925  0.246875]
# target 2 row 176 prediction
# o1 -> ['O1/theta', 'O1/alpha']
# o2 -> ['O2/theta', 'O2/alpha']
#
# [0.247875 0.871875 0.183875 0.569625 0.456875]
# [0.31375  0.81325  0.227875 0.405875 0.201375]
# target 2 row 184 prediction
# o1 -> ['O1/alpha', 'O1/betaH']
# o2 -> ['O2/alpha', 'O2/betaH']
#
# [0.203375 0.30875  0.62275  0.39325  0.441375]
# [0.234625 0.23375  0.51625  0.233375 0.268125]
# target 2 row 192 prediction
# o1 -> ['O1/betaL', 'O1/gamma']
# o2 -> ['O2/betaL', 'O2/gamma']
#
# [0.272625 0.505125 0.52575  0.636    0.254   ]
# [0.20825  0.493375 0.310125 0.2275   0.18275 ]
# target 2 row 200 prediction
# o1 -> ['O1/betaH', 'O1/betaL']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.181125 0.32425  0.18425  0.282125 0.231   ]
# [0.336625 0.858625 0.242875 0.143    0.136375]
# target 2 row 208 prediction
# o1 -> ['O1/alpha', 'O1/betaH']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.5      0.368    0.2475   0.398    0.462875]
# [0.316125 0.378125 0.138125 0.103625 0.217875]
# target 2 row 216 prediction
# o1 -> ['O1/theta', 'O1/gamma']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.238625 0.494    0.4275   0.425125 0.260125]
# [0.471625 0.69525  0.426125 0.28725  0.166   ]
# target 2 row 224 prediction
# o1 -> ['O1/alpha', 'O1/betaL']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.266    0.337375 0.244    0.416375 0.3005  ]
# [0.20575  1.20075  0.613    0.18675  0.153875]
# target 2 row 232 prediction
# o1 -> ['O1/betaH', 'O1/alpha']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.359875 0.669625 0.512125 0.700875 0.414625]
# [0.269625 0.3825   0.214625 0.2455   0.193125]
# target 2 row 240 prediction
# o1 -> ['O1/betaH', 'O1/alpha']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.560125 0.422125 0.445125 0.474    0.477125]
# [0.4315  0.42275 0.23875 0.24875 0.275  ]
# target 2 row 248 prediction
# o1 -> ['O1/theta', 'O1/gamma']
# o2 -> ['O2/theta', 'O2/alpha']
#
# [0.498    0.615625 0.423375 0.3445   0.511375]
# [0.60775  0.645875 0.274    0.09075  0.22075 ]
# target 2 row 256 prediction
# o1 -> ['O1/alpha', 'O1/gamma']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.347875 0.849    0.160375 0.50925  0.339875]
# [0.365125 0.591125 0.21025  0.18625  0.193125]
# target 2 row 264 prediction
# o1 -> ['O1/alpha', 'O1/betaH']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.9135   0.650125 0.138125 0.36475  0.344125]
# [0.727    0.420625 0.211125 0.21075  0.253625]
# target 2 row 272 prediction
# o1 -> ['O1/theta', 'O1/alpha']
# o2 -> ['O2/theta', 'O2/alpha']
#
# [0.318125 0.4815   0.317375 0.315375 0.402125]
# [0.1975   0.299    0.1855   0.12175  0.211125]
# target 2 row 280 prediction
# o1 -> ['O1/alpha', 'O1/gamma']
# o2 -> ['O2/alpha', 'O2/gamma']
#
# [0.55625  0.341125 0.3735   0.668125 0.41975 ]
# [0.5315   0.35275  0.423875 0.3445   0.195625]
# target 2 row 288 prediction
# o1 -> ['O1/betaH', 'O1/theta']
# o2 -> ['O2/theta', 'O2/betaL']
#
# [0.3645   0.786    0.612375 0.42925  0.50525 ]
# [0.27925 0.95325 0.50675 0.3855  0.233  ]
# target 2 row 296 prediction
# o1 -> ['O1/alpha', 'O1/betaL']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.171    0.343    0.300125 0.264125 0.2345  ]
# [0.196    0.378625 0.270125 0.172625 0.09125 ]
# target 2 row 304 prediction
# o1 -> ['O1/alpha', 'O1/betaL']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.291375 0.511125 0.496875 0.36975  0.434375]
# [0.201875 0.3605   0.258625 0.22825  0.228625]
# target 2 row 312 prediction
# o1 -> ['O1/alpha', 'O1/betaL']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.222625 0.172625 0.467375 0.48125  0.478125]
# [0.247625 0.12425  0.493    0.286375 0.247875]
# target 2 row 320 prediction
# o1 -> ['O1/betaH', 'O1/gamma']
# o2 -> ['O2/betaL', 'O2/betaH']
#
# [0.2375   0.473125 0.478125 0.462625 0.6195  ]
# [0.144375 0.32375  0.490125 0.277    0.203625]
# target 2 row 328 prediction
# o1 -> ['O1/gamma', 'O1/betaL']
# o2 -> ['O2/betaL', 'O2/alpha']
#
# [0.7125   0.35175  0.3095   0.382125 0.406625]
# [0.27975  0.331625 0.3995   0.26275  0.239375]
# target 2 row 336 prediction
# o1 -> ['O1/theta', 'O1/gamma']
# o2 -> ['O2/betaL', 'O2/alpha']
#
# [0.398875 0.6905   0.74775  0.26775  0.324375]
# [0.207    0.5505   0.689125 0.163    0.190125]
# target 2 row 344 prediction
# o1 -> ['O1/betaL', 'O1/alpha']
# o2 -> ['O2/betaL', 'O2/alpha']
#
# [0.218875 0.3865   0.422    0.38775  0.268375]
# [0.3175   0.82175  0.304375 0.229875 0.1365  ]
# target 2 row 352 prediction
# o1 -> ['O1/betaL', 'O1/betaH']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.470375 0.65975  0.52375  0.607625 0.327125]
# [0.251125 0.68625  0.48     0.36975  0.19725 ]
# target 2 row 360 prediction
# o1 -> ['O1/alpha', 'O1/betaH']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.4675   0.418125 0.424    0.6005   0.57925 ]
# [0.26225  0.38875  0.260625 0.203125 0.198375]
# target 2 row 368 prediction
# o1 -> ['O1/betaH', 'O1/gamma']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.54725  1.113    0.349375 0.273    0.374   ]
# [0.4735   0.6385   0.234    0.181875 0.175625]
# target 2 row 376 prediction
# o1 -> ['O1/alpha', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.196875 0.29575  0.197875 0.1955   0.58875 ]
# [0.139375 0.5625   0.504625 0.19975  0.3955  ]
# target 2 row 384 prediction
# o1 -> ['O1/gamma', 'O1/alpha']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.386375 0.841    0.352375 0.313625 0.424   ]
# [0.25675  1.8155   0.489375 0.18875  0.34425 ]
# target 2 row 392 prediction
# o1 -> ['O1/alpha', 'O1/gamma']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.307    0.365375 0.16175  0.429125 0.438   ]
# [0.2015   0.564375 0.230375 0.1955   0.200625]
# target 2 row 400 prediction
# o1 -> ['O1/gamma', 'O1/betaH']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.740625 0.56375  0.207375 0.424    0.33825 ]
# [0.620625 0.507875 0.6655   0.19625  0.21425 ]
# target 2 row 408 prediction
# o1 -> ['O1/theta', 'O1/alpha']
# o2 -> ['O2/betaL', 'O2/theta']
#
# [0.34625  0.41225  0.148625 0.218625 0.29725 ]
# [0.40275  0.559625 0.324875 0.25     0.16575 ]
# target 2 row 416 prediction
# o1 -> ['O1/alpha', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.484625 0.46925  0.419    0.296875 0.23925 ]
# [0.340125 0.20925  0.35425  0.182625 0.129875]
# target 2 row 424 prediction
# o1 -> ['O1/theta', 'O1/alpha']
# o2 -> ['O2/betaL', 'O2/theta']
#
# [0.423375 0.409375 0.43575  0.2735   0.387125]
# [0.18125  0.167375 0.27925  0.143375 0.182   ]
# target 2 row 432 prediction
# o1 -> ['O1/betaL', 'O1/theta']
# o2 -> ['O2/betaL', 'O2/gamma']
#
# [0.27275  0.21     0.426125 0.367875 0.296375]
# [0.22475  0.1025   0.55225  0.25475  0.260875]
# target 2 row 440 prediction
# o1 -> ['O1/betaL', 'O1/betaH']
# o2 -> ['O2/betaL', 'O2/gamma']
#
# [0.127625 0.311375 0.403375 0.391375 0.295375]
# [0.201    0.19025  0.231375 0.316    0.206625]
# target 2 row 448 prediction
# o1 -> ['O1/betaL', 'O1/betaH']
# o2 -> ['O2/betaH', 'O2/betaL']
#
# [0.519125 0.662875 0.208    0.345875 0.194125]
# [0.149875 0.23425  0.055    0.104125 0.095375]
# target 2 row 456 prediction
# o1 -> ['O1/alpha', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.655   0.85875 0.24225 0.335   0.19425]
# [0.231375 0.706625 0.125    0.158125 0.075625]
# target 2 row 464 prediction
# o1 -> ['O1/alpha', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.4775   0.71475  0.594875 0.44175  0.18675 ]
# [0.2115   0.630375 0.3515   0.22525  0.1365  ]
# target 2 row 472 prediction
# o1 -> ['O1/alpha', 'O1/betaL']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.486125 0.6095   0.212875 0.35225  0.29625 ]
# [0.36725  0.8985   0.30525  0.275    0.155375]
# target 2 row 480 prediction
# o1 -> ['O1/alpha', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.1055   0.494125 0.63975  0.480875 0.45575 ]
# [0.141125 0.4215   0.5965   0.23425  0.228625]
# target 2 row 488 prediction
# o1 -> ['O1/betaL', 'O1/alpha']
# o2 -> ['O2/betaL', 'O2/alpha']
#
# [0.226625 0.452875 0.4485   0.558375 0.687125]
# [0.157    0.364    0.349    0.325    0.264875]
# target 2 row 496 prediction
# o1 -> ['O1/gamma', 'O1/betaH']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.23025  0.21925  0.231125 0.21625  0.25975 ]
# [0.1855   0.136625 0.086    0.123375 0.093125]
# target 2 row 504 prediction
# o1 -> ['O1/gamma', 'O1/betaL']
# o2 -> ['O2/theta', 'O2/alpha']
#
# [0.359    0.412    0.563    0.21125  0.295375]
# [0.412625 0.278875 0.290625 0.08875  0.12425 ]
# target 2 row 512 prediction
# o1 -> ['O1/betaL', 'O1/alpha']
# o2 -> ['O2/theta', 'O2/betaL']
#
# [0.325625 0.306875 0.297375 0.24525  0.28525 ]
# [0.10025  0.234125 0.232375 0.179625 0.11975 ]
# target 2 row 520 prediction
# o1 -> ['O1/theta', 'O1/alpha']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.195375 0.285    0.41675  0.172625 0.20175 ]
# [0.119875 0.19625  0.3275   0.126625 0.152125]
# target 2 row 528 prediction
# o1 -> ['O1/betaL', 'O1/alpha']
# o2 -> ['O2/betaL', 'O2/alpha']
#
# [0.27475  0.42775  0.238875 0.197125 0.2095  ]
# [0.10825  0.2455   0.11675  0.069125 0.095875]
# target 2 row 536 prediction
# o1 -> ['O1/alpha', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.719   0.4055  0.3055  0.20625 0.20475]
# [0.682125 0.74     0.2      0.21375  0.173375]
# target 2 row 544 prediction
# o1 -> ['O1/theta', 'O1/alpha']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.384    0.750125 0.61175  0.255625 0.2215  ]
# [0.565125 0.908    0.86975  0.246    0.138875]
# target 2 row 552 prediction
# o1 -> ['O1/alpha', 'O1/betaL']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.2905   0.4355   0.237125 0.19225  0.1695  ]
# [0.423375 1.562875 0.6545   0.165375 0.109375]
# target 2 row 560 prediction
# o1 -> ['O1/alpha', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.300375 0.359    0.167875 0.209    0.1685  ]
# [0.509625 0.800375 0.369375 0.142875 0.141125]
# target 2 row 568 prediction
# o1 -> ['O1/alpha', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.397875 0.550875 0.285875 0.317875 0.276625]
# [0.241875 0.255    0.17375  0.14525  0.10075 ]
# target 2 row 576 prediction
# o1 -> ['O1/alpha', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.476    0.945125 0.242    0.28825  0.294125]
# [0.349875 0.529625 0.22     0.156875 0.115   ]
# target 2 row 584 prediction
# o1 -> ['O1/alpha', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.465375 1.110375 0.265375 0.276125 0.23225 ]
# [0.423125 0.894125 0.237875 0.133375 0.13525 ]
# target 2 row 592 prediction
# o1 -> ['O1/alpha', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.321375 1.893    1.6085   0.686    0.52775 ]
# [0.238    0.468375 0.64075  0.322125 0.222875]
# target 3 row 0 prediction
# o1 -> ['O1/alpha', 'O1/betaL']
# o2 -> ['O2/betaL', 'O2/alpha']
#
# [0.433375 1.02375  1.076125 0.5315   0.5355  ]
# [0.338875 0.56775  0.69125  0.38975  0.20025 ]
# target 3 row 8 prediction
# o1 -> ['O1/betaL', 'O1/alpha']
# o2 -> ['O2/betaL', 'O2/alpha']
#
# [0.314625 0.365125 0.629    0.383875 0.488375]
# [0.327625 0.34325  0.417875 0.24     0.2395  ]
# target 3 row 16 prediction
# o1 -> ['O1/betaL', 'O1/gamma']
# o2 -> ['O2/betaL', 'O2/alpha']
#
# [0.499375 0.453375 0.29075  0.351    0.535625]
# [0.271875 0.49225  0.4435   0.337625 0.2505  ]
# target 3 row 24 prediction
# o1 -> ['O1/gamma', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.47225  0.316875 0.492875 0.391125 0.5575  ]
# [0.39525  0.12725  0.278375 0.23275  0.207   ]
# target 3 row 32 prediction
# o1 -> ['O1/gamma', 'O1/betaL']
# o2 -> ['O2/theta', 'O2/betaL']
#
# [0.383625 1.015625 0.25075  0.617625 0.570375]
# [0.29975  0.38725  0.172625 0.17825  0.122   ]
# target 3 row 40 prediction
# o1 -> ['O1/alpha', 'O1/betaH']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.439375 1.048625 0.51225  0.614125 0.256   ]
# [0.236875 0.28775  0.35475  0.138375 0.1855  ]
# target 3 row 48 prediction
# o1 -> ['O1/alpha', 'O1/betaH']
# o2 -> ['O2/betaL', 'O2/alpha']
#
# [0.628625 1.0925   0.77025  0.828625 0.58    ]
# [0.294625 0.326875 0.17875  0.2985   0.20575 ]
# target 3 row 56 prediction
# o1 -> ['O1/alpha', 'O1/betaH']
# o2 -> ['O2/alpha', 'O2/betaH']
#
# [0.440875 0.649625 0.6335   0.6605   0.5895  ]
# [0.396875 0.5485   0.316    0.26225  0.220375]
# target 3 row 64 prediction
# o1 -> ['O1/betaH', 'O1/alpha']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.229375 1.25825  1.141125 0.6705   0.4965  ]
# [0.35575 2.12625 1.3755  0.16075 0.32975]
# target 3 row 72 prediction
# o1 -> ['O1/alpha', 'O1/betaL']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.56025  0.941625 1.35975  0.6125   0.818125]
# [0.585375 1.1075   0.200625 0.234125 0.330125]
# target 3 row 80 prediction
# o1 -> ['O1/betaL', 'O1/alpha']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.363875 0.636375 0.463875 0.60725  0.768625]
# [0.275125 0.85425  0.361875 0.225875 0.454875]
# target 3 row 88 prediction
# o1 -> ['O1/gamma', 'O1/alpha']
# o2 -> ['O2/alpha', 'O2/gamma']
#
# [0.335625 0.31275  0.468    0.581375 0.4025  ]
# [0.295    0.45325  0.754625 0.344125 0.242375]
# target 3 row 96 prediction
# o1 -> ['O1/betaH', 'O1/betaL']
# o2 -> ['O2/betaL', 'O2/alpha']
#
# [0.6465  0.47775 0.276   0.4885  0.67175]
# [0.6645   0.88575  0.314625 0.389625 0.405   ]
# target 3 row 104 prediction
# o1 -> ['O1/gamma', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.5375   1.18475  0.476125 0.65025  0.524875]
# [0.680625 1.713375 0.533125 0.310625 0.329875]
# target 3 row 112 prediction
# o1 -> ['O1/alpha', 'O1/betaH']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.342125 0.517625 0.286875 0.336875 0.358875]
# [0.220375 0.316375 0.16575  0.2215   0.243875]
# target 3 row 120 prediction
# o1 -> ['O1/alpha', 'O1/gamma']
# o2 -> ['O2/alpha', 'O2/gamma']
#
# [0.237    0.7045   0.292125 0.285375 0.477   ]
# [0.286   0.49775 0.33875 0.26925 0.25325]
# target 3 row 128 prediction
# o1 -> ['O1/alpha', 'O1/gamma']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.401625 1.04225  0.459875 0.39525  0.407125]
# [0.398625 0.539125 0.362    0.192625 0.2735  ]
# target 3 row 136 prediction
# o1 -> ['O1/alpha', 'O1/betaL']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.528    0.613    0.5495   0.516875 0.480625]
# [0.364125 0.500125 0.325375 0.3955   0.286   ]
# target 3 row 144 prediction
# o1 -> ['O1/alpha', 'O1/betaL']
# o2 -> ['O2/alpha', 'O2/betaH']
#
# [0.793875 0.730125 0.73275  0.3885   0.504125]
# [0.326375 0.126    0.390875 0.26575  0.249125]
# target 3 row 152 prediction
# o1 -> ['O1/theta', 'O1/betaL']
# o2 -> ['O2/betaL', 'O2/theta']
#
# [0.52125  0.429125 0.533125 0.546875 0.43425 ]
# [0.381    0.42875  0.24025  0.310875 0.242875]
# target 3 row 160 prediction
# o1 -> ['O1/betaH', 'O1/betaL']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.324375 0.56725  0.5525   0.56625  0.59525 ]
# [0.392375 0.40525  0.707625 0.400625 0.264375]
# target 3 row 168 prediction
# o1 -> ['O1/gamma', 'O1/alpha']
# o2 -> ['O2/betaL', 'O2/alpha']
#
# [0.187375 0.481375 0.505375 0.580625 0.596375]
# [0.164    0.532625 0.46625  0.372875 0.257375]
# target 3 row 176 prediction
# o1 -> ['O1/gamma', 'O1/betaH']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.278625 0.74325  0.9075   0.630875 0.6745  ]
# [0.369125 0.521375 0.478875 0.381    0.406   ]
# target 3 row 184 prediction
# o1 -> ['O1/betaL', 'O1/alpha']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.346875 0.3045   0.3405   0.177625 0.197875]
# [0.38575  0.154375 0.1895   0.15625  0.166   ]
# target 3 row 192 prediction
# o1 -> ['O1/theta', 'O1/betaL']
# o2 -> ['O2/theta', 'O2/betaL']
#
# [0.474625 0.316875 0.216    0.33175  0.395   ]
# [0.301    0.210625 0.092125 0.30175  0.186   ]
# target 3 row 200 prediction
# o1 -> ['O1/theta', 'O1/gamma']
# o2 -> ['O2/betaH', 'O2/theta']
#
# [0.695875 0.31625  0.121125 0.454375 0.7715  ]
# [0.30275 0.38625 0.11425 0.30675 0.39425]
# target 3 row 208 prediction
# o1 -> ['O1/gamma', 'O1/theta']
# o2 -> ['O2/gamma', 'O2/alpha']
#
# [0.2805   1.10225  0.468125 0.5      0.585125]
# [0.298125 1.069875 0.398125 0.273875 0.30375 ]
# target 3 row 216 prediction
# o1 -> ['O1/alpha', 'O1/gamma']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.213375 0.82925  0.46     0.458    0.377875]
# [0.195   0.83775 0.393   0.33425 0.185  ]
# target 3 row 224 prediction
# o1 -> ['O1/alpha', 'O1/betaL']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.113375 0.32775  0.25975  0.709375 0.5435  ]
# [0.145    0.264    0.11175  0.35625  0.232375]
# target 3 row 232 prediction
# o1 -> ['O1/betaH', 'O1/gamma']
# o2 -> ['O2/betaH', 'O2/alpha']
#
# [0.1705   0.145375 0.22775  0.293625 0.493125]
# [0.182375 0.194125 0.4235   0.199875 0.222625]
# target 3 row 240 prediction
# o1 -> ['O1/gamma', 'O1/betaH']
# o2 -> ['O2/betaL', 'O2/gamma']
#
# [0.277    0.112    0.246125 0.36675  0.323   ]
# [0.220125 0.355875 0.540875 0.203375 0.186375]
# target 3 row 248 prediction
# o1 -> ['O1/betaH', 'O1/gamma']
# o2 -> ['O2/betaL', 'O2/alpha']
#
# [0.381375 0.321625 0.329125 0.5145   0.29175 ]
# [0.398    0.545875 0.447375 0.252875 0.222375]
# target 3 row 256 prediction
# o1 -> ['O1/betaH', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.321625 0.154125 0.194875 0.375    0.346   ]
# [0.178625 0.20075  0.19875  0.1905   0.127375]
# target 3 row 264 prediction
# o1 -> ['O1/betaH', 'O1/gamma']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.269375 0.630625 0.237    0.75375  0.356875]
# [0.177375 0.313125 0.147375 0.332875 0.16975 ]
# target 3 row 272 prediction
# o1 -> ['O1/betaH', 'O1/alpha']
# o2 -> ['O2/betaH', 'O2/alpha']
#
# [0.515    1.125625 0.14175  0.45675  0.40125 ]
# [0.54325  1.035375 0.153125 0.270125 0.208125]
# target 3 row 280 prediction
# o1 -> ['O1/alpha', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.279    0.358    0.627625 0.338125 0.412375]
# [0.222625 0.508    0.388375 0.218875 0.228125]
# target 3 row 288 prediction
# o1 -> ['O1/betaL', 'O1/gamma']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.302875 0.358375 0.213875 0.2935   0.27275 ]
# [0.235125 0.5365   0.18425  0.279375 0.0835  ]
# target 3 row 296 prediction
# o1 -> ['O1/alpha', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/betaH']
#
# [0.5385   0.468375 0.614625 0.464625 0.27875 ]
# [0.398625 0.31175  0.367625 0.244625 0.0865  ]
# target 3 row 304 prediction
# o1 -> ['O1/betaL', 'O1/theta']
# o2 -> ['O2/theta', 'O2/betaL']
#
# [0.467375 0.7405   0.31     0.3995   0.52325 ]
# [0.4705   0.531625 0.430625 0.278125 0.330625]
# target 3 row 312 prediction
# o1 -> ['O1/alpha', 'O1/gamma']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.594625 0.2535   0.329    0.555    0.425625]
# [0.5035   0.3385   0.304125 0.328375 0.197875]
# target 3 row 320 prediction
# o1 -> ['O1/theta', 'O1/betaH']
# o2 -> ['O2/theta', 'O2/alpha']
#
# [0.48175  0.335375 0.36325  0.3215   0.521   ]
# [0.347125 0.372875 0.57725  0.234875 0.217625]
# target 3 row 328 prediction
# o1 -> ['O1/gamma', 'O1/theta']
# o2 -> ['O2/betaL', 'O2/alpha']
#
# [0.253125 0.35325  0.50025  0.183    0.388   ]
# [0.3195  0.434   0.4235  0.159   0.16275]
# target 3 row 336 prediction
# o1 -> ['O1/betaL', 'O1/gamma']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.147875 0.26775  0.502375 0.27825  0.44825 ]
# [0.214875 0.5035   0.5305   0.215375 0.2825  ]
# target 3 row 344 prediction
# o1 -> ['O1/betaL', 'O1/gamma']
# o2 -> ['O2/betaL', 'O2/alpha']
#
# [0.508125 0.54875  0.35     0.324875 0.40725 ]
# [0.553625 0.6755   0.344875 0.2175   0.27175 ]
# target 3 row 352 prediction
# o1 -> ['O1/alpha', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.47925  0.34     0.278125 0.305875 0.444125]
# [0.257625 0.472375 0.281125 0.24275  0.267875]
# target 3 row 360 prediction
# o1 -> ['O1/theta', 'O1/gamma']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.1975   0.469875 0.259125 0.40875  0.5     ]
# [0.217625 0.572125 0.3145   0.2175   0.2945  ]
# target 3 row 368 prediction
# o1 -> ['O1/gamma', 'O1/alpha']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.31325  0.65425  0.196125 0.5865   0.375875]
# [0.23475  0.665875 0.308125 0.42325  0.190625]
# target 3 row 376 prediction
# o1 -> ['O1/alpha', 'O1/betaH']
# o2 -> ['O2/alpha', 'O2/betaH']
#
# [0.481875 0.55875  0.241625 0.223125 0.261375]
# [0.236375 0.4715   0.169375 0.168    0.128625]
# target 3 row 384 prediction
# o1 -> ['O1/alpha', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.332625 0.489125 0.16225  0.2345   0.510625]
# [0.25625  0.42425  0.152125 0.178    0.17925 ]
# target 3 row 392 prediction
# o1 -> ['O1/gamma', 'O1/alpha']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.350125 0.320125 0.25725  0.279    0.489   ]
# [0.18075  0.261    0.233625 0.138625 0.269375]
# target 3 row 400 prediction
# o1 -> ['O1/gamma', 'O1/theta']
# o2 -> ['O2/gamma', 'O2/alpha']
#
# [0.39225 0.3105  0.46425 0.50175 0.482  ]
# [0.35275  0.22825  0.38125  0.262375 0.190375]
# target 3 row 408 prediction
# o1 -> ['O1/betaH', 'O1/gamma']
# o2 -> ['O2/betaL', 'O2/theta']
#
# [0.421125 0.3465   0.24275  0.446125 0.345125]
# [0.338    0.159625 0.16175  0.170375 0.131375]
# target 3 row 416 prediction
# o1 -> ['O1/betaH', 'O1/theta']
# o2 -> ['O2/theta', 'O2/betaH']
#
# [0.3985   0.357625 0.38325  0.421875 0.404625]
# [0.224625 0.195875 0.076625 0.145125 0.10725 ]
# target 3 row 424 prediction
# o1 -> ['O1/betaH', 'O1/gamma']
# o2 -> ['O2/theta', 'O2/alpha']
#
# [0.7205  0.5825  0.188   0.29575 0.3495 ]
# [0.336125 0.18125  0.256375 0.138625 0.126375]
# target 3 row 432 prediction
# o1 -> ['O1/theta', 'O1/alpha']
# o2 -> ['O2/theta', 'O2/betaL']
#
# [1.56675  0.612125 0.241    0.34925  0.3125  ]
# [1.1275   0.873125 0.27825  0.1765   0.151   ]
# target 3 row 440 prediction
# o1 -> ['O1/theta', 'O1/alpha']
# o2 -> ['O2/theta', 'O2/alpha']
#
# [0.22425  0.337375 0.247    0.28725  0.20475 ]
# [0.171875 0.433625 0.160125 0.15225  0.089   ]
# target 3 row 448 prediction
# o1 -> ['O1/alpha', 'O1/betaH']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.302625 0.248375 0.46975  0.36825  0.309   ]
# [0.492875 0.272    0.236125 0.26575  0.191375]
# target 3 row 456 prediction
# o1 -> ['O1/betaL', 'O1/betaH']
# o2 -> ['O2/theta', 'O2/alpha']
#
# [0.294125 0.461    0.37     0.54075  0.394875]
# [0.32875  0.24525  0.254625 0.26625  0.23075 ]
# target 3 row 464 prediction
# o1 -> ['O1/betaH', 'O1/alpha']
# o2 -> ['O2/theta', 'O2/betaH']
#
# [0.313125 0.44875  0.201625 0.271875 0.25175 ]
# [0.38575  0.347375 0.239    0.24     0.207125]
# target 3 row 472 prediction
# o1 -> ['O1/alpha', 'O1/theta']
# o2 -> ['O2/theta', 'O2/alpha']
#
# [0.391  0.3305 0.1825 0.2445 0.4455]
# [0.43675  0.30375  0.15275  0.13625  0.179875]
# target 3 row 480 prediction
# o1 -> ['O1/gamma', 'O1/theta']
# o2 -> ['O2/theta', 'O2/alpha']
#
# [0.28775  0.290625 0.543875 0.509125 0.374125]
# [0.298    0.319125 0.233625 0.168    0.156375]
# target 3 row 488 prediction
# o1 -> ['O1/betaL', 'O1/betaH']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.2205   0.246625 0.418125 0.497    0.4075  ]
# [0.156    0.273375 0.279125 0.33425  0.1475  ]
# target 3 row 496 prediction
# o1 -> ['O1/betaH', 'O1/betaL']
# o2 -> ['O2/betaH', 'O2/betaL']
#
# [0.255125 0.4165   0.277375 0.34625  0.26525 ]
# [0.095375 0.471375 0.21225  0.11125  0.11525 ]
# target 3 row 504 prediction
# o1 -> ['O1/alpha', 'O1/betaH']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.49225  0.384125 0.376125 0.302125 0.278125]
# [0.208625 0.408    0.336875 0.170375 0.169125]
# target 3 row 512 prediction
# o1 -> ['O1/theta', 'O1/alpha']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.13525  0.20925  0.225625 0.254625 0.328625]
# [0.4195   0.3155   0.248    0.216125 0.23775 ]
# target 3 row 520 prediction
# o1 -> ['O1/gamma', 'O1/betaH']
# o2 -> ['O2/theta', 'O2/alpha']
#
# [0.466375 0.1735   0.16075  0.2255   0.210625]
# [0.316625 0.15175  0.172    0.0935   0.100125]
# target 3 row 528 prediction
# o1 -> ['O1/theta', 'O1/betaH']
# o2 -> ['O2/theta', 'O2/betaL']
#
# [0.29275  0.76575  0.557875 0.265875 0.15325 ]
# [0.290125 0.18375  0.272875 0.16925  0.15375 ]
# target 3 row 536 prediction
# o1 -> ['O1/alpha', 'O1/betaL']
# o2 -> ['O2/theta', 'O2/betaL']
#
# [0.141625 0.8015   0.5005   0.25875  0.26475 ]
# [0.153375 0.164875 0.154625 0.122375 0.1495  ]
# target 3 row 544 prediction
# o1 -> ['O1/alpha', 'O1/betaL']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.432125 0.25075  0.154375 0.3135   0.29575 ]
# [0.268    0.295125 0.1975   0.10225  0.110625]
# target 3 row 552 prediction
# o1 -> ['O1/theta', 'O1/betaH']
# o2 -> ['O2/alpha', 'O2/theta']
#
# [0.28875  0.487    0.396875 0.296875 0.248   ]
# [0.202875 0.3865   0.26275  0.14975  0.104375]
# target 3 row 560 prediction
# o1 -> ['O1/alpha', 'O1/betaL']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.495625 0.948625 0.3005   0.226375 0.221875]
# [0.316125 0.526    0.350875 0.12475  0.119125]
# target 3 row 568 prediction
# o1 -> ['O1/alpha', 'O1/theta']
# o2 -> ['O2/alpha', 'O2/betaL']
#
# [0.2135   0.2635   0.32225  0.37125  0.162125]
# [0.096125 0.11975  0.120375 0.07675  0.052875]
# target 3 row 576 prediction
# o1 -> ['O1/betaH', 'O1/betaL']
# o2 -> ['O2/betaL', 'O2/alpha']
# [0.164875 0.260375 0.287125 0.2765   0.193375]
# [0.2705   0.237625 0.3095   0.191625 0.10225 ]
# target 3 row 584 prediction
# o1 -> ['O1/betaL', 'O1/betaH']
# o2 -> ['O2/betaL', 'O2/theta']
#
# [0.218125 0.500875 0.544    0.17325  0.145125]
# [0.261875 1.       1.055625 0.15275  0.165   ]
# target 3 row 592 prediction
# o1 -> ['O1/betaL', 'O1/alpha']
# o2 -> ['O2/betaL', 'O2/alpha']
